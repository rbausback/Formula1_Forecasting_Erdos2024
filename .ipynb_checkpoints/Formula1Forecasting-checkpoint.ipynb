# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from bs4 import BeautifulSoup
import requests

# %%
response= requests.get("https://www.formula1.com/en/results.html/2023/races/1141/bahrain/practice-1.html")

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
response.text
# Out:
# '\n\n<!DOCTYPE html>\n\n<!--[if IE 8 ]> <html class="nojs lt-ie10 lte-ie9 ie8" lang="en"> <![endif]-->\n<!--[if IE 9 ]> <html class="nojs lt-ie10 ie9" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!-->\n\n\n\n\n<html itemscope itemtype="http://schema.org/Website" class="no-js editmode-false" lang="en">\n\n<!--<![endif]-->\n\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8"/>\n\t<meta name="viewport" content="width=device-width, initial-scale=1"/>\n    <meta name="robots" content="max-image-preview:large"/>\n\n    \n<title>\n\n\n    \n    \n        FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023\n        \n        \n        \n        \n        \n        \n        \n        \n        \n        \n        \n         - PRACTICE 1\n        \n        \n        \n        \n        \n    \n\n\n\n\n</title>\n<meta i
# ...

# %%
t = soup.title

# %%
t
# Out:
# <title>
#
#
#
#
#         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023
#
#
#
#
#
#
#
#
#
#
#
#          - PRACTICE 1
#
#
#
#
#
#
#
#
#
#
# </title>

# %%
table = soup.find_all('table')

# %%
table
# Out:
# [<table class="resultsarchive-table">
#  <thead>
#  <tr>
#  <th class="limiter"></th>
#  <th><abbr title="Position">Pos</abbr></th>
#  <th class="hide-for-mobile"><abbr title="Number">No</abbr></th>
#  <th>Driver</th>
#  <th class="hide-for-tablet">Car</th>
#  <th>Time</th>
#  <th>Gap</th>
#  <th>Laps</th>
#  <th class="limiter"></th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="limiter"></td>
#  <td class="dark">1</td>
#  <td class="dark hide-for-mobile">11</td>
#  <td class="dark bold">
#  <span class="hide-for-tablet">Sergio</span>
#  <span class="hide-for-mobile">Perez</span>
#  <span class="uppercase hide-for-desktop">PER</span>
#  </td>
#  <td class="semi-bold uppercase hide-for-tablet">Red Bull Racing Honda RBPT</td>
#  <td class="dark bold">1:32.758</td>
#  <td class="dark bold"> </td>
#  <td class="bold">21</td>
#  <td class="limiter"></td>
#  </tr>
#  <tr>
#  <td class="limiter"></td>
#  <td class="dark">2</td>
#  <td class="dark hide-for-mobile">14</td>
# ...

# %%
df =pd.read_html(str(table))[0]
# Out:
# C:\Users\Xaalt\AppData\Local\Temp\ipykernel_10492\30873026.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table))[0]

# %%
df
# Out:
#     Unnamed: 0  Pos  No               Driver                           Car  \
# 0          NaN    1  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 1          NaN    2  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 2          NaN    3   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 3          NaN    4   4     Lando Norris NOR              McLaren Mercedes
# 4          NaN    5  16  Charles Leclerc LEC                       Ferrari
# 5          NaN    6  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 6          NaN    7  20  Kevin Magnussen MAG                  Haas Ferrari
# 7          NaN    8  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 8          NaN    9  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 9          NaN   10  44   Lewis Hamilton HAM                      Mercedes
# 10         NaN   11  63   George Russell RUS                      Mercedes
# ...

# %%
response2= requests.get("https://www.formula1.com/en/results.html/2023/races/1141/bahrain/practice-2.html")

# %%
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.text, 'html.parser')

# %%
table2 = soup2.find_all('table')

# %%
df2 =pd.read_html(str(table2))[0]
# Out:
# C:\Users\Xaalt\AppData\Local\Temp\ipykernel_10492\2343750769.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 =pd.read_html(str(table2))[0]

# %%
df2
# Out:
#     Unnamed: 0  Pos  No               Driver                           Car  \
# 0          NaN    1  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 1          NaN    2   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 2          NaN    3  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 3          NaN    4  16  Charles Leclerc LEC                       Ferrari
# 4          NaN    5  27  Nico Hulkenberg HUL                  Haas Ferrari
# 5          NaN    6  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 6          NaN    7  10     Pierre Gasly GAS                Alpine Renault
# 7          NaN    8  44   Lewis Hamilton HAM                      Mercedes
# 8          NaN    9   4     Lando Norris NOR              McLaren Mercedes
# 9          NaN   10  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 10         NaN   11  31     Esteban Ocon OCO                Alpine Renault
# ...

# %%
df2_1 = df2.drop(columns=["Unnamed: 0", "Unnamed: 8"])

# %%
df2_1["Gap"].iloc[0]='+0.0s'
# Out:
# C:\Users\Xaalt\AppData\Local\Temp\ipykernel_10492\1395580554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_1["Gap"].iloc[0]='+0.0s'

# %%
df2_1
# Out:
#     Pos  No               Driver                           Car      Time  \
# 0     1  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes  1:30.907
# 1     2   1   Max Verstappen VER    Red Bull Racing Honda RBPT  1:31.076
# 2     3  11     Sergio Perez PER    Red Bull Racing Honda RBPT  1:31.078
# 3     4  16  Charles Leclerc LEC                       Ferrari  1:31.367
# 4     5  27  Nico Hulkenberg HUL                  Haas Ferrari  1:31.376
# 5     6  18     Lance Stroll STR  Aston Martin Aramco Mercedes  1:31.450
# 6     7  10     Pierre Gasly GAS                Alpine Renault  1:31.475
# 7     8  44   Lewis Hamilton HAM                      Mercedes  1:31.543
# 8     9   4     Lando Norris NOR              McLaren Mercedes  1:31.570
# 9    10  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari  1:31.586
# 10   11  31     Esteban Ocon OCO                Alpine Renault  1:31.608
# 11   12  77  Valtteri Bottas BOT            Alfa Romeo Ferrari  1:31.793
# ...

# %%
df["Race"]=soup.title.text.replace('\n','')

# %%
df
# Out:
#     Unnamed: 0  Pos  No               Driver                           Car  \
# 0          NaN    1  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 1          NaN    2  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 2          NaN    3   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 3          NaN    4   4     Lando Norris NOR              McLaren Mercedes
# 4          NaN    5  16  Charles Leclerc LEC                       Ferrari
# 5          NaN    6  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 6          NaN    7  20  Kevin Magnussen MAG                  Haas Ferrari
# 7          NaN    8  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 8          NaN    9  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 9          NaN   10  44   Lewis Hamilton HAM                      Mercedes
# 10         NaN   11  63   George Russell RUS                      Mercedes
# ...

# %%
df["Race"].iloc[0].replace(' ','')
# Out:
# 'FORMULA1GULFAIRBAHRAINGRANDPRIX2023-PRACTICE1'
