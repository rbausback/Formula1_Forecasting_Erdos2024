# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import csv

# %%
# result
url = "https://www.formula1.com/en/results.html/2024/races/1234/miami/race-result.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Miami2024_result.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_27252\3840524842.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table))[0]
#    Pos  No                Driver                           Car  Laps  \
# 0    1   4      Lando Norris NOR              McLaren Mercedes    57
# 1    2   1    Max Verstappen VER    Red Bull Racing Honda RBPT    57
# 2    3  16   Charles Leclerc LEC                       Ferrari    57
# 3    4  11      Sergio Perez PER    Red Bull Racing Honda RBPT    57
# 4    5  55      Carlos Sainz SAI                       Ferrari    57
# 5    6  44    Lewis Hamilton HAM                      Mercedes    57
# 6    7  22      Yuki Tsunoda TSU                 RB Honda RBPT    57
# 7    8  63    George Russell RUS                      Mercedes    57
# 8    9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes    57
# ...

# %%
# practice 1
url = "https://www.formula1.com/en/results.html/2024/races/1234/miami/practice-1.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Miami2024_p1.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_27252\2146870735.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table))[0]
#     Pos  No                Driver                           Car      Time  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT  1:28.595
# 1     2  81     Oscar Piastri PIA              McLaren Mercedes  1:28.700
# 2     3  55      Carlos Sainz SAI                       Ferrari  1:28.711
# 3     4  63    George Russell RUS                      Mercedes  1:28.784
# 4     5  18      Lance Stroll STR  Aston Martin Aramco Mercedes  1:28.817
# 5     6  11      Sergio Perez PER    Red Bull Racing Honda RBPT  1:28.868
# 6     7  44    Lewis Hamilton HAM                      Mercedes  1:29.012
# 7     8  22      Yuki Tsunoda TSU                 RB Honda RBPT  1:29.056
# ...

# %%
# Q 
url = "https://www.formula1.com/en/results.html/2024/races/1234/miami/qualifying.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Miami2024_Q.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_27252\314762131.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table))[0]
#     Pos  No                Driver                           Car        Q1  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT  1:27.689
# 1     2  16   Charles Leclerc LEC                       Ferrari  1:28.081
# 2     3  55      Carlos Sainz SAI                       Ferrari  1:27.937
# 3     4  11      Sergio Perez PER    Red Bull Racing Honda RBPT  1:27.772
# 4     5   4      Lando Norris NOR              McLaren Mercedes  1:27.913
# 5     6  81     Oscar Piastri PIA              McLaren Mercedes  1:28.032
# 6     7  63    George Russell RUS                      Mercedes  1:28.159
# 7     8  44    Lewis Hamilton HAM                      Mercedes  1:28.167
# ...
