# %% [markdown]
# ### Saudi 2024

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import csv

# %%
# result
url = "https://www.formula1.com/en/results.html/2024/races/1230/saudi-arabia/race-result.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Saudi2024_result.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15260\292992557.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table_html))[0]
#     Pos  No                Driver                           Car  Laps  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT    57
# 1     2  11      Sergio Perez PER    Red Bull Racing Honda RBPT    57
# 2     3  55      Carlos Sainz SAI                       Ferrari    57
# 3     4  16   Charles Leclerc LEC                       Ferrari    57
# 4     5  63    George Russell RUS                      Mercedes    57
# 5     6   4      Lando Norris NOR              McLaren Mercedes    57
# 6     7  44    Lewis Hamilton HAM                      Mercedes    57
# 7     8  81     Oscar Piastri PIA              McLaren Mercedes    57
# 8     9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes    57
# 9    10  18      Lance Stroll STR  Aston Martin Aramco Mercedes    57
# 10   11  24       Zhou Guanyu ZHO           Kick Sauber Ferrari    56
# 11   12  20   Kevin Magnussen MAG                  Haas Ferrari    56
# 12   13   3  Daniel Ricciardo RIC                 RB Honda RBPT    56
# 13   14  22      Yuki Tsunoda TSU                 RB Honda RBPT    56
# 14   15  23   Alexander Albon ALB             Williams Mercedes    56
# 15   16  27   Nico Hulkenberg HUL                  Haas Ferrari    56
# 16   17  31      Esteban Ocon OCO                Alpine Renault    56
# 17   18  10      Pierre Gasly GAS                Alpine Renault    56
# 18   19  77   Valtteri Bottas BOT           Kick Sauber Ferrari    56
# 19   20   2    Logan Sargeant SAR             Williams Mercedes    55
#
#    Time/Retired  PTS
# 0   1:31:44.742   26
# 1      +22.457s   18
# 2      +25.110s   15
# 3      +39.669s   12
# 4      +46.788s   10
# 5      +48.458s    8
# 6      +50.324s    6
# 7      +56.082s    4
# 8      +74.887s    2
# 9      +93.216s    1
# 10       +1 lap    0
# 11       +1 lap    0
# 12       +1 lap    0
# 13       +1 lap    0
# 14       +1 lap    0
# 15       +1 lap    0
# 16       +1 lap    0
# 17       +1 lap    0
# 18       +1 lap    0
# 19      +2 laps    0

# %%
# practice 1
url = "https://www.formula1.com/en/results.html/2024/races/1230/saudi-arabia/practice-1.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Saudi2024_p1.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15260\1982986639.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table_html))[0]
#     Pos  No                Driver                           Car  Laps  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT    57
# 1     2  11      Sergio Perez PER    Red Bull Racing Honda RBPT    57
# 2     3  55      Carlos Sainz SAI                       Ferrari    57
# 3     4  16   Charles Leclerc LEC                       Ferrari    57
# 4     5  63    George Russell RUS                      Mercedes    57
# 5     6   4      Lando Norris NOR              McLaren Mercedes    57
# 6     7  44    Lewis Hamilton HAM                      Mercedes    57
# 7     8  81     Oscar Piastri PIA              McLaren Mercedes    57
# 8     9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes    57
# 9    10  18      Lance Stroll STR  Aston Martin Aramco Mercedes    57
# 10   11  24       Zhou Guanyu ZHO           Kick Sauber Ferrari    56
# 11   12  20   Kevin Magnussen MAG                  Haas Ferrari    56
# 12   13   3  Daniel Ricciardo RIC                 RB Honda RBPT    56
# 13   14  22      Yuki Tsunoda TSU                 RB Honda RBPT    56
# 14   15  23   Alexander Albon ALB             Williams Mercedes    56
# 15   16  27   Nico Hulkenberg HUL                  Haas Ferrari    56
# 16   17  31      Esteban Ocon OCO                Alpine Renault    56
# 17   18  10      Pierre Gasly GAS                Alpine Renault    56
# 18   19  77   Valtteri Bottas BOT           Kick Sauber Ferrari    56
# 19   20   2    Logan Sargeant SAR             Williams Mercedes    55
#
#    Time/Retired  PTS
# 0   1:31:44.742   26
# 1      +22.457s   18
# 2      +25.110s   15
# 3      +39.669s   12
# 4      +46.788s   10
# 5      +48.458s    8
# 6      +50.324s    6
# 7      +56.082s    4
# 8      +74.887s    2
# 9      +93.216s    1
# 10       +1 lap    0
# 11       +1 lap    0
# 12       +1 lap    0
# 13       +1 lap    0
# 14       +1 lap    0
# 15       +1 lap    0
# 16       +1 lap    0
# 17       +1 lap    0
# 18       +1 lap    0
# 19      +2 laps    0

# %%
# practice 2
url = "https://www.formula1.com/en/results.html/2024/races/1230/saudi-arabia/practice-2.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Saudi2024_p2.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15260\4098603784.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table_html))[0]
#     Pos  No                Driver                           Car  Laps  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT    57
# 1     2  11      Sergio Perez PER    Red Bull Racing Honda RBPT    57
# 2     3  55      Carlos Sainz SAI                       Ferrari    57
# 3     4  16   Charles Leclerc LEC                       Ferrari    57
# 4     5  63    George Russell RUS                      Mercedes    57
# 5     6   4      Lando Norris NOR              McLaren Mercedes    57
# 6     7  44    Lewis Hamilton HAM                      Mercedes    57
# 7     8  81     Oscar Piastri PIA              McLaren Mercedes    57
# 8     9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes    57
# 9    10  18      Lance Stroll STR  Aston Martin Aramco Mercedes    57
# 10   11  24       Zhou Guanyu ZHO           Kick Sauber Ferrari    56
# 11   12  20   Kevin Magnussen MAG                  Haas Ferrari    56
# 12   13   3  Daniel Ricciardo RIC                 RB Honda RBPT    56
# 13   14  22      Yuki Tsunoda TSU                 RB Honda RBPT    56
# 14   15  23   Alexander Albon ALB             Williams Mercedes    56
# 15   16  27   Nico Hulkenberg HUL                  Haas Ferrari    56
# 16   17  31      Esteban Ocon OCO                Alpine Renault    56
# 17   18  10      Pierre Gasly GAS                Alpine Renault    56
# 18   19  77   Valtteri Bottas BOT           Kick Sauber Ferrari    56
# 19   20   2    Logan Sargeant SAR             Williams Mercedes    55
#
#    Time/Retired  PTS
# 0   1:31:44.742   26
# 1      +22.457s   18
# 2      +25.110s   15
# 3      +39.669s   12
# 4      +46.788s   10
# 5      +48.458s    8
# 6      +50.324s    6
# 7      +56.082s    4
# 8      +74.887s    2
# 9      +93.216s    1
# 10       +1 lap    0
# 11       +1 lap    0
# 12       +1 lap    0
# 13       +1 lap    0
# 14       +1 lap    0
# 15       +1 lap    0
# 16       +1 lap    0
# 17       +1 lap    0
# 18       +1 lap    0
# 19      +2 laps    0

# %%
# practice 3
url = "https://www.formula1.com/en/results.html/2024/races/1230/saudi-arabia/practice-3.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Saudi2024_p3.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15260\1313279316.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table_html))[0]
#     Pos  No                Driver                           Car  Laps  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT    57
# 1     2  11      Sergio Perez PER    Red Bull Racing Honda RBPT    57
# 2     3  55      Carlos Sainz SAI                       Ferrari    57
# 3     4  16   Charles Leclerc LEC                       Ferrari    57
# 4     5  63    George Russell RUS                      Mercedes    57
# 5     6   4      Lando Norris NOR              McLaren Mercedes    57
# 6     7  44    Lewis Hamilton HAM                      Mercedes    57
# 7     8  81     Oscar Piastri PIA              McLaren Mercedes    57
# 8     9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes    57
# 9    10  18      Lance Stroll STR  Aston Martin Aramco Mercedes    57
# 10   11  24       Zhou Guanyu ZHO           Kick Sauber Ferrari    56
# 11   12  20   Kevin Magnussen MAG                  Haas Ferrari    56
# 12   13   3  Daniel Ricciardo RIC                 RB Honda RBPT    56
# 13   14  22      Yuki Tsunoda TSU                 RB Honda RBPT    56
# 14   15  23   Alexander Albon ALB             Williams Mercedes    56
# 15   16  27   Nico Hulkenberg HUL                  Haas Ferrari    56
# 16   17  31      Esteban Ocon OCO                Alpine Renault    56
# 17   18  10      Pierre Gasly GAS                Alpine Renault    56
# 18   19  77   Valtteri Bottas BOT           Kick Sauber Ferrari    56
# 19   20   2    Logan Sargeant SAR             Williams Mercedes    55
#
#    Time/Retired  PTS
# 0   1:31:44.742   26
# 1      +22.457s   18
# 2      +25.110s   15
# 3      +39.669s   12
# 4      +46.788s   10
# 5      +48.458s    8
# 6      +50.324s    6
# 7      +56.082s    4
# 8      +74.887s    2
# 9      +93.216s    1
# 10       +1 lap    0
# 11       +1 lap    0
# 12       +1 lap    0
# 13       +1 lap    0
# 14       +1 lap    0
# 15       +1 lap    0
# 16       +1 lap    0
# 17       +1 lap    0
# 18       +1 lap    0
# 19      +2 laps    0

# %%
# practice 1
url = "https://www.formula1.com/en/results.html/2024/races/1230/saudi-arabia/qualifying.html"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', class_='resultsarchive-table')
df =pd.read_html(str(table))[0]
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv('2024_CSV/Saudi2024_Q.csv', index=False)
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15260\2117692485.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df =pd.read_html(str(table_html))[0]
#     Pos  No                Driver                           Car  Laps  \
# 0     1   1    Max Verstappen VER    Red Bull Racing Honda RBPT    57
# 1     2  11      Sergio Perez PER    Red Bull Racing Honda RBPT    57
# 2     3  55      Carlos Sainz SAI                       Ferrari    57
# 3     4  16   Charles Leclerc LEC                       Ferrari    57
# 4     5  63    George Russell RUS                      Mercedes    57
# 5     6   4      Lando Norris NOR              McLaren Mercedes    57
# 6     7  44    Lewis Hamilton HAM                      Mercedes    57
# 7     8  81     Oscar Piastri PIA              McLaren Mercedes    57
# 8     9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes    57
# 9    10  18      Lance Stroll STR  Aston Martin Aramco Mercedes    57
# 10   11  24       Zhou Guanyu ZHO           Kick Sauber Ferrari    56
# 11   12  20   Kevin Magnussen MAG                  Haas Ferrari    56
# 12   13   3  Daniel Ricciardo RIC                 RB Honda RBPT    56
# 13   14  22      Yuki Tsunoda TSU                 RB Honda RBPT    56
# 14   15  23   Alexander Albon ALB             Williams Mercedes    56
# 15   16  27   Nico Hulkenberg HUL                  Haas Ferrari    56
# 16   17  31      Esteban Ocon OCO                Alpine Renault    56
# 17   18  10      Pierre Gasly GAS                Alpine Renault    56
# 18   19  77   Valtteri Bottas BOT           Kick Sauber Ferrari    56
# 19   20   2    Logan Sargeant SAR             Williams Mercedes    55
#
#    Time/Retired  PTS
# 0   1:31:44.742   26
# 1      +22.457s   18
# 2      +25.110s   15
# 3      +39.669s   12
# 4      +46.788s   10
# 5      +48.458s    8
# 6      +50.324s    6
# 7      +56.082s    4
# 8      +74.887s    2
# 9      +93.216s    1
# 10       +1 lap    0
# 11       +1 lap    0
# 12       +1 lap    0
# 13       +1 lap    0
# 14       +1 lap    0
# 15       +1 lap    0
# 16       +1 lap    0
# 17       +1 lap    0
# 18       +1 lap    0
# 19      +2 laps    0
