# %%
## F1 practice and grid data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import set_style
set_style("whitegrid")

import pandas as pd
import numpy as np
import math
import requests
from bs4 import BeautifulSoup

# %%
## Put all the possible years in a list.
url = 'https://pitwall.app/races'
html = requests.get(url)
soup = BeautifulSoup(html.text, 'html.parser')
ul = soup.find('ul', attrs = {'class':'options'})
possible_years = [x.text for x in ul.find_all('a')]

# %%
## Define a function that converts minutes to seconds.
def convert(t):
    if ':' in t:
        sec_from_min = float(t.split(':')[0]) * 60
        sec = float(t.split(':')[1])
        return sec_from_min + sec
    else:
        return float(t)

# %%
F1 = pd.DataFrame(columns=['Season',
                               'Grand Prix',
                               'Driver',
                               'Constructor',
                               'FP1 Time','FP1 Gap','FP1 Laps',
                               'FP2 Time','FP2 Gap','FP2 Laps',
                               'FP3 Time','FP3 Gap','FP3 Laps',
                               'Grid Position', 'Qualifying Time'])

## You can slice possible_years
for year in possible_years[:10]: # range of seasons
    url = 'https://pitwall.app/races/archive/' + year
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    tbody = soup.find('tbody')
    possible_races = [x['href'] for x in tbody.find_all('a')]

    ## You can slice possible races
    for race in possible_races: # range of races in a given season
        url = 'https://pitwall.app/races/' + year + race[11:]
        html = requests.get(url)
        soup = BeautifulSoup(html.text, 'html.parser')
        print('')
        print('working on', race)
        print('')
        
        ### Get the Free Practice data ###
        
        ## Get FP1
        FP1 = soup.find('div', attrs = {'id':'free_practice_1'})
        data_1 = []
        if FP1 != None:
            FP1_table = FP1.find('table', attrs = {'class':'data-table'})
            body = FP1_table.find('tbody')
            rows_1 = body.find_all('tr')
            data_1 = []
            for row in rows_1:
                row_data = []
                for cell in row.find_all('td')[1:]:
                    row_data.append(cell.text)
                ## Name
                name = row_data[0].split(' ')[2]
                row_data[0] = name
                ## Time
                if row_data[2] != '':
                    row_data[2] = round(convert(row_data[2]), 3)
                else:
                    row_data[2] = np.nan
                ## Gap
                if row_data[3] == '':
                    row_data[3] = 0 
                else:
                    if row_data[3] != '':
                        row_data[3] = float(convert(row_data[3].replace('+','')))
                    else:
                        row_data[3] = np.nan
                ## Lap
                if row_data[4] != '':
                    row_data[4] = float(row_data[4])
                else:
                    row_data[4] = np.nan
                data_1.append(row_data)
            print(data_1)
            print('')
        else:
            print('FP1 does not exists')
            print('')
        
        ## Get FP2
        FP2 = soup. find('div', attrs = {'id':'free_practice_2'}) 
        data_2 = []
        if FP2 != None:
            FP2_table = FP2.find('table', attrs = {'class':'data-table'})
            body = FP2_table.find('tbody')
            rows_2 = body.find_all('tr')
            for row in rows_2:
                row_data = []
                for cell in row.find_all('td')[1:]:
                    row_data.append(cell.text)
                ## Name
                name = row_data[0].split(' ')[2]
                row_data[0] = name
                ## Time
                if row_data[2] != '':
                    row_data[2] = round(convert(row_data[2]), 3)
                else:
                    row_data[2] = np.nan
                ## Gap
                if row_data[3] == '':
                    row_data[3] = 0 
                else:
                    if row_data[3] != '':
                        row_data[3] = float(convert(row_data[3].replace('+','')))
                    else:
                        row_data[3] = np.nan
                ## Lap
                if row_data[4] != '':
                    row_data[4] = float(row_data[4])
                else:
                    row_data[4] = np.nan
                data_2.append(row_data)
            print(data_2)    
            print('')
            ## Update data_1
            for row in data_1:
                if row[0] in [x[0] for x in data_2]:
                    index = [x[0] for x in data_2].index(row[0])
                    for i in data_2[index][2:]:
                        row.append(i)
                else:
                    row = [y for x in [row, [np.nan, np.nan, np.nan]] for y in x]
        else:
            print('FP2 does not exists')
            print('')
        
        ## Get FP3
        FP3 = soup.find('div', attrs = {'id':'free_practice_3'})
        data_3 = []
        if FP3 != None:
            FP3_table = FP3.find('table', attrs = {'class':'data-table'})
            body = FP3_table.find('tbody')
            rows_3 = body.find_all('tr')
            for row in rows_3:
                row_data = []
                for cell in row.find_all('td')[1:]:
                        row_data.append(cell.text)
                ## Name
                name = row_data[0].split(' ')[2]
                row_data[0] = name
                ## Time
                if row_data[2] != '':
                    row_data[2] = round(convert(row_data[2]), 3)
                else:
                    row_data[2] = np.nan
                ## Gap
                if row_data[3] == '':
                    row_data[3] = 0 
                else:
                    if row_data[3] != '':
                        row_data[3] = float(convert(row_data[3].replace('+','')))
                    else:
                        row_data[3] = np.nan
                ## Lap
                if row_data[4] != '':
                    row_data[4] = float(row_data[4])
                else:
                    row_data[4] = np.nan
                data_3.append(row_data)
            print(data_3)
            print('')
            ## Update data_1
            for row in data_1:
                if row[0] in [x[0] for x in data_3]:
                    index = [x[0] for x in data_3].index(row[0])
                    for i in data_3[index][2:]:
                        row.append(i)
                else:
                    row = [y for x in [row, [np.nan, np.nan, np.nan]] for y in x]
        else:
            print('FP3 does not exists')
            print('')
        
        ### Get the Starting grid ###
        grid = soup.find('div', attrs = {'id':'qualifying'})
        if grid != None:
            grid_table = grid.find('table', attrs = {'class':'data-table'})
            body = grid_table.find('tbody')
            rows_grid = body.find_all('tr')
            row_data_names = []
            row_data_times = []
            
            for row in rows_grid:
                for cell in row.find_all('td')[1:2]:
                    name = cell.text
                    row_data_names.append(name)
            
            row_data_names = [x.split(' ')[2] for x in row_data_names]
            
            for row in rows_grid:
                for cell in row.find_all('td')[4:5]:
                    time = cell.text
                    if time == '':
                        row_data_times.append(np.nan)
                    else:
                        row_data_times.append(time)
#             row_data_times = [round(convert(x), 3) for x in row_data_times] 
            
            ## Update data_1
            for row in data_1:
                if row[0] in row_data_names:
                    index = row_data_names.index(row[0])
                    row.append(index + 1)
                else:
                    row.append(np.nan)
                if row[0] in row_data_names:
                    index = row_data_names.index(row[0])
                    row.append(row_data_times[index]) 
                else:
                    row.append(np.nan)    
        else:
            print('Grid does not exist')
            print('')
            
        
        ### Update the data frame ###
        if (FP1 != None) and (FP2 != None) and (FP3 != None) and (grid != None):
            ## Make clean dataframes for the current race and year.
            L = [year, race[12:]]
            data_1 = [L + x for x in data_1]
            df = pd.DataFrame(data_1, columns=['Season',
                                   'Grand Prix',
                                   'Driver',
                                   'Constructor',
                                   'FP1 Time','FP1 Gap','FP1 Laps',
                                   'FP2 Time','FP2 Gap','FP2 Laps',
                                   'FP3 Time','FP3 Gap','FP3 Laps',
                                   'Grid Position', 'Qualifying Time'])
            F1 = pd.concat([F1, df])
# Out:
# working on /races/2023-bahrain-grand-prix
#
# [['Pérez', 'Red Bull', 92.758, 0, 21.0], ['Alonso', 'Aston Martin', 93.196, 0.438, 22.0], ['Verstappen', 'Red Bull', 93.375, 0.617, 21.0], ['Norris', 'McLaren', 94.165, 1.407, 21.0], ['Leclerc', 'Ferrari', 94.257, 1.499, 17.0], ['Stroll', 'Aston Martin', 94.298, 1.54, 17.0], ['Magnussen', 'Haas', 94.402, 1.644, 20.0], ['Zhou', 'Alfa Romeo', 94.575, 1.817, 18.0], ['Bottas', 'Alfa Romeo', 94.689, 1.931, 20.0], ['Hamilton', 'Mercedes', 94.917, 2.159, 13.0], ['Russell', 'Mercedes', 94.966, 2.208, 20.0], ['Piastri', 'McLaren', 94.997, 2.239, 24.0], ['Tsunoda', 'AlphaTauri', 95.015, 2.257, 20.0], ['Hülkenberg', 'Haas', 95.043, 2.285, 22.0], ['Ocon', 'Alpine', 95.105, 2.347, 20.0], ['de', 'AlphaTauri', 95.402, 2.644, 25.0], ['Gasly', 'Alpine', 95.455, 2.697, 22.0], ['Sargeant', 'Williams', 95.749, 2.991, 24.0], ['Albon', 'Williams', 96.018, 3.26, 15.0], ['Sainz', 'Ferrari', 96.072, 3.314, 21.0]]
#
# [['Alonso', 'Aston Martin', 90.907, 0, 25.0], ['Verstappen', 'Red Bull', 91.076, 0.169, 24.0], ['Pérez', 'Red Bull', 91.078, 0.171, 26.0], ['Leclerc', 'Ferrari', 91.367, 0.46, 26.0], ['Hülkenberg', 'Haas', 91.376, 0.469, 25.0], ['Stroll', 'Aston Martin', 91.45, 0.543, 28.0], ['Gasly', 'Alpine', 91.475, 0.568, 24.0], ['Hamilton', 'Mercedes', 91.543, 0.636, 27.0], ['Norris', 'McLaren', 91.57, 0.663, 27.0], ['Zhou', 'Alfa Romeo', 91.586, 0.679, 27.0], ['Ocon', 'Alpine', 91.608, 0.701, 25.0], ['Bottas', 'Alfa Romeo', 91.793, 0.886, 28.0], ['Russell', 'Mercedes', 91.882, 0.975, 25.0], ['Sainz', 'Ferrari', 91.956, 1.049, 28.0], ['Piastri', 'McLaren', 92.024, 1.117, 27.0], ['Magnussen', 'Haas', 92.11, 1.203, 18.0], ['Albon', 'Williams', 92.44, 1.533, 28.0], ['Tsunoda', 'AlphaTauri', 92.525, 1.618, 27.0], ['de', 'AlphaTauri', 92.605, 1.698, 28.0], ['Sargeant', 'Williams', 92.749, 1.842, 29.0]]
#
# [['Alonso', 'Aston Martin', 92.34, 0, 13.0], ['Verstappen', 'Red Bull', 92.345, 0.005, 13.0], ['Pérez', 'Red Bull', 92.446, 0.106, 12.0], ['Hamilton', 'Mercedes', 92.555, 0.215, 17.0], ['Leclerc', 'Ferrari', 92.624, 0.284, 21.0], ['Russell', 'Mercedes', 92.731, 0.391, 17.0], ['Stroll', 'Aston Martin', 92.919, 0.579, 16.0], ['Sainz', 'Ferrari', 92.945, 0.605, 21.0], ['Piastri', 'McLaren', 93.045, 0.705, 12.0], ['Gasly', 'Alpine', 93.064, 0.724, 13.0], ['Ocon', 'Alpine', 93.116, 0.776, 16.0], ['Zhou', 'Alfa Romeo', 93.18, 0.84, 13.0], ['Norris', 'McLaren', 93.202, 0.862, 16.0], ['Magnussen', 'Haas', 93.381, 1.041, 21.0], ['Hülkenberg', 'Haas', 93.423, 1.083, 23.0], ['Tsunoda', 'AlphaTauri', 93.475, 1.135, 15.0], ['Bottas', 'Alfa Romeo', 93.629, 1.289, 14.0], ['Sargeant', 'Williams', 93.665, 1.325, 15.0], ['Albon', 'Williams', 93.882, 1.542, 15.0], ['de', 'AlphaTauri', 94.082, 1.742, 18.0]]
# /var/folders/yd/kp6bpgzj2x5211sc99wjp9z80000gn/T/ipykernel_96991/3825416461.py:218: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   F1 = pd.concat([F1, df])
# working on /races/2023-saudi-arabian-grand-prix
#
# [['Verstappen', 'Red Bull', 89.617, 0, 18.0], ['Pérez', 'Red Bull', 90.1, 0.483, 20.0], ['Alonso', 'Aston Martin', 90.315, 0.698, 22.0], ['Stroll', 'Aston Martin', 90.577, 0.96, 20.0], ['Russell', 'Mercedes', 90.771, 1.154, 26.0], ['Hamilton', 'Mercedes', 90.787, 1.17, 26.0], ['Sainz', 'Ferrari', 90.924, 1.307, 23.0], ['Gasly', 'Alpine', 90.949, 1.332, 24.0], ['Albon', 'Williams', 91.03, 1.413, 23.0], ['Tsunoda', 'AlphaTauri', 91.11, 1.493, 25.0], ['Leclerc', 'Ferrari', 91.118, 1.501, 26.0], ['Ocon', 'Alpine', 91.181, 1.564, 22.0], ['de', 'AlphaTauri', 91.45, 1.833, 29.0], ['Piastri', 'McLaren', 91.491, 1.874, 24.0], ['Hülkenberg', 'Haas', 91.552, 1.935, 22.0], ['Magnussen', 'Haas', 91.566, 1.949, 23.0], ['Sargeant', 'Williams', 91.922, 2.305, 26.0], ['Bottas', 'Alfa Romeo', 91.97, 2.353, 25.0], ['Zhou', 'Alfa Romeo', 91.986, 2.369, 22.0], ['Norris', 'McLaren', 92.149, 2.532, 21.0]]
#
# [['Verstappen', 'Red Bull', 89.603, 0, 29.0], ['Alonso', 'Aston Martin', 89.811, 0.208, 26.0], ['Pérez', 'Red Bull', 89.902, 0.299, 26.0], ['Ocon', 'Alpine', 90.039, 0.436, 27.0], ['Russell', 'Mercedes', 90.07, 0.467, 27.0], ['Gasly', 'Alpine', 90.1, 0.497, 28.0], ['Stroll', 'Aston Martin', 90.11, 0.507, 27.0], ['Hülkenberg', 'Haas', 90.181, 0.578, 27.0], ['Leclerc', 'Ferrari', 90.341, 0.738, 28.0], ['Sainz', 'Ferrari', 90.592, 0.989, 29.0], ['Hamilton', 'Mercedes', 90.599, 0.996, 27.0], ['Norris', 'McLaren', 90.721, 1.118, 27.0], ['Tsunoda', 'AlphaTauri', 90.776, 1.173, 30.0], ['Albon', 'Williams', 90.81, 1.207, 27.0], ['Magnussen', 'Haas', 90.82, 1.217, 25.0], ['Zhou', 'Alfa Romeo', 90.837, 1.234, 27.0], ['de', 'AlphaTauri', 90.921, 1.318, 29.0], ['Sargeant', 'Williams', 90.959, 1.356, 30.0], ['Piastri', 'McLaren', 90.964, 1.361, 26.0], ['Bottas', 'Alfa Romeo', 91.052, 1.449, 30.0]]
#
# [['Verstappen', 'Red Bull', 88.485, 0, 20.0], ['Pérez', 'Red Bull', 89.098, 0.613, 15.0], ['Alonso', 'Aston Martin', 89.483, 0.998, 21.0], ['Stroll', 'Aston Martin', 89.509, 1.024, 21.0], ['Hamilton', 'Mercedes', 89.568, 1.083, 18.0], ['Leclerc', 'Ferrari', 89.588, 1.103, 16.0], ['Norris', 'McLaren', 89.69, 1.205, 18.0], ['Piastri', 'McLaren', 89.698, 1.213, 23.0], ['Gasly', 'Alpine', 89.701, 1.216, 19.0], ['Sainz', 'Ferrari', 89.761, 1.276, 16.0], ['Russell', 'Mercedes', 89.811, 1.326, 19.0], ['Zhou', 'Alfa Romeo', 89.917, 1.432, 21.0], ['Hülkenberg', 'Haas', 89.933, 1.448, 19.0], ['Ocon', 'Alpine', 89.953, 1.468, 19.0], ['Albon', 'Williams', 89.983, 1.498, 18.0], ['Sargeant', 'Williams', 90.035, 1.55, 18.0], ['Magnussen', 'Haas', 90.131, 1.646, 15.0], ['Bottas', 'Alfa Romeo', 90.317, 1.832, 20.0], ['Tsunoda', 'AlphaTauri', 90.797, 2.312, 20.0]]
#
#
# working on /races/2023-australian-grand-prix
#
# [['Verstappen', 'Red Bull', 78.79, 0, 17.0], ['Hamilton', 'Mercedes', 79.223, 0.433, 20.0], ['Pérez', 'Red Bull', 79.293, 0.503, 19.0], ['Alonso', 'Aston Martin', 79.317, 0.527, 23.0], ['Leclerc', 'Ferrari', 79.378, 0.588, 16.0], ['Sainz', 'Ferrari', 79.505, 0.715, 20.0], ['Norris', 'McLaren', 79.536, 0.746, 16.0], ['Gasly', 'Alpine', 79.646, 0.856, 22.0], ['Russell', 'Mercedes', 79.699, 0.909, 23.0], ['Stroll', 'Aston Martin', 79.766, 0.976, 19.0], ['Albon', 'Williams', 79.766, 0.976, 21.0], ['Piastri', 'McLaren', 79.777, 0.987, 22.0], ['Hülkenberg', 'Haas', 79.806, 1.016, 19.0], ['de', 'AlphaTauri', 79.933, 1.143, 25.0], ['Sargeant', 'Williams', 80.074, 1.284, 21.0], ['Ocon', 'Alpine', 80.175, 1.385, 20.0], ['Tsunoda', 'AlphaTauri', 80.399, 1.609, 14.0], ['Bottas', 'Alfa Romeo', 80.419, 1.629, 21.0], ['Zhou', 'Alfa Romeo', 80.569, 1.779, 22.0], ['Magnussen', 'Haas', 81.147, 2.357, 17.0]]
#
# [['Alonso', 'Aston Martin', 78.887, 0, 13.0], ['Leclerc', 'Ferrari', 79.332, 0.445, 10.0], ['Verstappen', 'Red Bull', 79.502, 0.615, 12.0], ['Russell', 'Mercedes', 79.672, 0.785, 20.0], ['Sainz', 'Ferrari', 79.695, 0.808, 12.0], ['Ocon', 'Alpine', 79.725, 0.838, 12.0], ['Pérez', 'Red Bull', 80.083, 1.196, 15.0], ['Norris', 'McLaren', 80.176, 1.289, 20.0], ['Hülkenberg', 'Haas', 80.194, 1.307, 19.0], ['Gasly', 'Alpine', 80.206, 1.319, 12.0], ['Tsunoda', 'AlphaTauri', 80.22, 1.333, 18.0], ['Bottas', 'Alfa Romeo', 80.312, 1.425, 22.0], ['Hamilton', 'Mercedes', 80.323, 1.436, 17.0], ['Piastri', 'McLaren', 80.38, 1.493, 24.0], ['Zhou', 'Alfa Romeo', 80.47, 1.583, 22.0], ['Stroll', 'Aston Martin', 80.579, 1.692, 15.0], ['de', 'AlphaTauri', 80.6, 1.713, 8.0], ['Albon', 'Williams', 81.182, 2.295, 18.0], ['Magnussen', 'Haas', 81.266, 2.379, 18.0]]
#
# [['Verstappen', 'Red Bull', 77.565, 0, 24.0], ['Alonso', 'Aston Martin', 77.727, 0.162, 26.0], ['Ocon', 'Alpine', 77.938, 0.373, 23.0], ['Russell', 'Mercedes', 77.955, 0.39, 23.0], ['Gasly', 'Alpine', 78.094, 0.529, 23.0], ['Pérez', 'Red Bull', 78.123, 0.558, 18.0], ['Sainz', 'Ferrari', 78.127, 0.562, 29.0], ['Hamilton', 'Mercedes', 78.138, 0.573, 25.0], ['Stroll', 'Aston Martin', 78.198, 0.633, 22.0], ['Zhou', 'Alfa Romeo', 78.33, 0.765, 20.0], ['Hülkenberg', 'Haas', 78.41, 0.845, 24.0], ['Albon', 'Williams', 78.553, 0.988, 21.0], ['Leclerc', 'Ferrari', 78.691, 1.126, 28.0], ['Piastri', 'McLaren', 78.713, 1.148, 21.0], ['Bottas', 'Alfa Romeo', 78.809, 1.244, 24.0], ['Tsunoda', 'AlphaTauri', 78.901, 1.336, 22.0], ['Sargeant', 'Williams', 78.947, 1.382, 20.0], ['Magnussen', 'Haas', 79.056, 1.491, 26.0], ['de', 'AlphaTauri', 79.092, 1.527, 23.0], ['Norris', 'McLaren', 79.146, 1.581, 12.0]]
#
#
# working on /races/2023-azerbaijan-grand-prix
#
# [['Verstappen', 'Red Bull', 102.315, 0, 22.0], ['Leclerc', 'Ferrari', 102.352, 0.037, 21.0], ['Pérez', 'Red Bull', 102.454, 0.139, 22.0], ['Sainz', 'Ferrari', 102.899, 0.584, 23.0], ['Norris', 'McLaren', 103.125, 0.81, 22.0], ['de', 'AlphaTauri', 103.414, 1.099, 24.0], ['Stroll', 'Aston Martin', 103.455, 1.14, 23.0], ['Alonso', 'Aston Martin', 103.56, 1.245, 20.0], ['Albon', 'Williams', 103.628, 1.313, 25.0], ['Zhou', 'Alfa Romeo', 103.748, 1.433, 23.0], ['Hamilton', 'Mercedes', 103.798, 1.483, 21.0], ['Piastri', 'McLaren', 103.98, 1.665, 23.0], ['Bottas', 'Alfa Romeo', 104.01, 1.695, 23.0], ['Tsunoda', 'AlphaTauri', 104.137, 1.822, 18.0], ['Hülkenberg', 'Haas', 104.323, 2.008, 21.0], ['Sargeant', 'Williams', 104.9, 2.585, 16.0], ['Russell', 'Mercedes', 105.082, 2.767, 20.0], ['Ocon', 'Alpine', 105.955, 3.64, 8.0], ['Gasly', 'Alpine', 106.321, 4.006, 7.0], ['Magnussen', 'Haas', 107.498, 5.183, 8.0]]
#
# FP2 does not exists
#
# FP3 does not exists
#
#
# working on /races/2023-miami-grand-prix
#
# [['Russell', 'Mercedes', 90.125, 0, 18.0], ['Hamilton', 'Mercedes', 90.337, 0.212, 24.0], ['Leclerc', 'Ferrari', 90.449, 0.324, 23.0], ['Verstappen', 'Red Bull', 90.549, 0.424, 22.0], ['Sainz', 'Ferrari', 90.724, 0.599, 23.0], ['Gasly', 'Alpine', 91.104, 0.979, 20.0], ['Alonso', 'Aston Martin', 91.231, 1.106, 24.0], ['Stroll', 'Aston Martin', 91.337, 1.212, 24.0], ['Hülkenberg', 'Haas', 91.392, 1.267, 14.0], ['Ocon', 'Alpine', 91.542, 1.417, 27.0], ['Pérez', 'Red Bull', 91.566, 1.441, 22.0], ['Piastri', 'McLaren', 91.81, 1.685, 24.0], ['Magnussen', 'Haas', 91.853, 1.728, 25.0], ['Bottas', 'Alfa Romeo', 91.902, 1.777, 24.0], ['Albon', 'Williams', 91.903, 1.778, 25.0], ['Norris', 'McLaren', 91.997, 1.872, 23.0], ['Zhou', 'Alfa Romeo', 92.134, 2.009, 22.0], ['Tsunoda', 'AlphaTauri', 92.169, 2.044, 28.0], ['Sargeant', 'Williams', 92.619, 2.494, 27.0], ['de', 'AlphaTauri', 94.637, 4.512, 10.0]]
#
# [['Verstappen', 'Red Bull', 87.93, 0, 23.0], ['Sainz', 'Ferrari', 88.315, 0.385, 26.0], ['Leclerc', 'Ferrari', 88.398, 0.468, 20.0], ['Pérez', 'Red Bull', 88.419, 0.489, 24.0], ['Alonso', 'Aston Martin', 88.66, 0.73, 25.0], ['Norris', 'McLaren', 88.741, 0.811, 24.0], ['Hamilton', 'Mercedes', 88.858, 0.928, 23.0], ['Stroll', 'Aston Martin', 88.93, 1.0, 23.0], ['Ocon', 'Alpine', 88.937, 1.007, 25.0], ['Albon', 'Williams', 89.046, 1.116, 26.0], ['Gasly', 'Alpine', 89.098, 1.168, 22.0], ['Magnussen', 'Haas', 89.171, 1.241, 22.0], ['Zhou', 'Alfa Romeo', 89.181, 1.251, 27.0], ['Bottas', 'Alfa Romeo', 89.189, 1.259, 26.0], ['Russell', 'Mercedes', 89.216, 1.286, 21.0], ['Piastri', 'McLaren', 89.339, 1.409, 24.0], ['Hülkenberg', 'Haas', 89.393, 1.463, 22.0], ['Tsunoda', 'AlphaTauri', 89.613, 1.683, 25.0], ['de', 'AlphaTauri', 89.928, 1.998, 25.0], ['Sargeant', 'Williams', 90.038, 2.108, 27.0]]
#
# [['Verstappen', 'Red Bull', 87.535, 0, 18.0], ['Leclerc', 'Ferrari', 87.941, 0.406, 26.0], ['Pérez', 'Red Bull', 88.05, 0.515, 22.0], ['Sainz', 'Ferrari', 88.125, 0.59, 27.0], ['Ocon', 'Alpine', 88.407, 0.872, 25.0], ['Gasly', 'Alpine', 88.428, 0.893, 24.0], ['Bottas', 'Alfa Romeo', 88.456, 0.921, 19.0], ['Hülkenberg', 'Haas', 88.497, 0.962, 16.0], ['Albon', 'Williams', 88.561, 1.026, 20.0], ['Russell', 'Mercedes', 88.606, 1.071, 20.0], ['Magnussen', 'Haas', 88.607, 1.072, 14.0], ['Alonso', 'Aston Martin', 88.618, 1.083, 24.0], ['Hamilton', 'Mercedes', 88.718, 1.183, 23.0], ['Stroll', 'Aston Martin', 88.723, 1.188, 24.0], ['Zhou', 'Alfa Romeo', 89.074, 1.539, 19.0], ['Tsunoda', 'AlphaTauri', 89.179, 1.644, 20.0], ['Sargeant', 'Williams', 89.264, 1.729, 20.0], ['Piastri', 'McLaren', 89.375, 1.84, 18.0], ['Norris', 'McLaren', 89.401, 1.866, 18.0], ['de', 'AlphaTauri', 89.447, 1.912, 22.0]]
# working on /races/2023-monaco-grand-prix
#
# [['Sainz', 'Ferrari', 73.372, 0, 26.0], ['Alonso', 'Aston Martin', 73.71, 0.338, 28.0], ['Hamilton', 'Mercedes', 74.035, 0.663, 27.0], ['Pérez', 'Red Bull', 74.038, 0.666, 27.0], ['Leclerc', 'Ferrari', 74.093, 0.721, 24.0], ['Verstappen', 'Red Bull', 74.244, 0.872, 26.0], ['Norris', 'McLaren', 74.467, 1.095, 25.0], ['Ocon', 'Alpine', 74.585, 1.213, 29.0], ['Stroll', 'Aston Martin', 74.653, 1.281, 28.0], ['Albon', 'Williams', 74.666, 1.294, 32.0], ['Bottas', 'Alfa Romeo', 74.718, 1.346, 29.0], ['Magnussen', 'Haas', 74.725, 1.353, 29.0], ['Tsunoda', 'AlphaTauri', 74.82, 1.448, 29.0], ['Gasly', 'Alpine', 74.866, 1.494, 30.0], ['Russell', 'Mercedes', 75.066, 1.694, 24.0], ['de', 'AlphaTauri', 75.083, 1.711, 33.0], ['Piastri', 'McLaren', 75.192, 1.82, 32.0], ['Sargeant', 'Williams', 75.557, 2.185, 30.0], ['Zhou', 'Alfa Romeo', 75.684, 2.312, 25.0], ['Hülkenberg', 'Haas', 75.785, 2.413, 17.0]]
#
# [['Verstappen', 'Red Bull', 72.462, 0, 30.0], ['Leclerc', 'Ferrari', 72.527, 0.065, 33.0], ['Sainz', 'Ferrari', 72.569, 0.107, 22.0], ['Alonso', 'Aston Martin', 72.682, 0.22, 32.0], ['Norris', 'McLaren', 72.906, 0.444, 18.0], ['Hamilton', 'Mercedes', 72.96, 0.498, 29.0], ['Pérez', 'Red Bull', 72.991, 0.529, 30.0], ['Bottas', 'Alfa Romeo', 73.05, 0.588, 33.0], ['Gasly', 'Alpine', 73.089, 0.627, 28.0], ['Ocon', 'Alpine', 73.162, 0.7, 30.0], ['Stroll', 'Aston Martin', 73.185, 0.723, 31.0], ['Russell', 'Mercedes', 73.191, 0.729, 32.0], ['Zhou', 'Alfa Romeo', 73.354, 0.892, 32.0], ['Magnussen', 'Haas', 73.457, 0.995, 28.0], ['Hülkenberg', 'Haas', 73.52, 1.058, 33.0], ['Tsunoda', 'AlphaTauri', 73.641, 1.179, 22.0], ['de', 'AlphaTauri', 73.663, 1.201, 34.0], ['Piastri', 'McLaren', 73.673, 1.211, 30.0], ['Albon', 'Williams', 74.217, 1.755, 10.0], ['Sargeant', 'Williams', 74.238, 1.776, 33.0]]
#
# [['Verstappen', 'Red Bull', 72.776, 0, 19.0], ['Pérez', 'Red Bull', 72.849, 0.073, 24.0], ['Stroll', 'Aston Martin', 72.942, 0.166, 20.0], ['Sainz', 'Ferrari', 73.261, 0.485, 20.0], ['Norris', 'McLaren', 73.396, 0.62, 21.0], ['Gasly', 'Alpine', 73.453, 0.677, 24.0], ['Leclerc', 'Ferrari', 73.475, 0.699, 19.0], ['Hamilton', 'Mercedes', 73.486, 0.71, 17.0], ['Ocon', 'Alpine', 73.496, 0.72, 18.0], ['Bottas', 'Alfa Romeo', 73.521, 0.745, 20.0], ['Russell', 'Mercedes', 73.59, 0.814, 18.0], ['Magnussen', 'Haas', 73.624, 0.848, 13.0], ['Hülkenberg', 'Haas', 73.65, 0.874, 16.0], ['Alonso', 'Aston Martin', 73.697, 0.921, 18.0], ['Tsunoda', 'AlphaTauri', 73.738, 0.962, 21.0], ['Zhou', 'Alfa Romeo', 73.772, 0.996, 20.0], ['Sargeant', 'Williams', 73.851, 1.075, 19.0], ['Albon', 'Williams', 73.93, 1.154, 23.0], ['Piastri', 'McLaren', 73.998, 1.222, 18.0], ['de', 'AlphaTauri', 74.187, 1.411, 24.0]]
#
#
# working on /races/2023-spanish-grand-prix
#
# [['Verstappen', 'Red Bull', 74.606, 0, 32.0], ['Pérez', 'Red Bull', 75.374, 0.768, 32.0], ['Ocon', 'Alpine', 75.418, 0.812, 28.0], ['de', 'AlphaTauri', 75.504, 0.898, 27.0], ['Gasly', 'Alpine', 75.545, 0.939, 27.0], ['Alonso', 'Aston Martin', 75.547, 0.941, 24.0], ['Magnussen', 'Haas', 75.689, 1.083, 22.0], ['Leclerc', 'Ferrari', 75.694, 1.088, 28.0], ['Sainz', 'Ferrari', 75.726, 1.12, 27.0], ['Russell', 'Mercedes', 75.753, 1.147, 32.0], ['Norris', 'McLaren', 75.783, 1.177, 25.0], ['Hamilton', 'Mercedes', 75.845, 1.239, 29.0], ['Zhou', 'Alfa Romeo', 75.906, 1.3, 24.0], ['Tsunoda', 'AlphaTauri', 75.915, 1.309, 27.0], ['Stroll', 'Aston Martin', 75.939, 1.333, 25.0], ['Bottas', 'Alfa Romeo', 75.978, 1.372, 24.0], ['Piastri', 'McLaren', 76.353, 1.747, 26.0], ['Hülkenberg', 'Haas', 76.461, 1.855, 28.0], ['Sargeant', 'Williams', 76.506, 1.9, 30.0], ['Albon', 'Williams', 76.63, 2.024, 28.0]]
#
# [['Verstappen', 'Red Bull', 73.907, 0, 34.0], ['Alonso', 'Aston Martin', 74.077, 0.17, 30.0], ['Hülkenberg', 'Haas', 74.177, 0.27, 31.0], ['Pérez', 'Red Bull', 74.219, 0.312, 30.0], ['Ocon', 'Alpine', 74.242, 0.335, 30.0], ['Leclerc', 'Ferrari', 74.246, 0.339, 32.0], ['Sainz', 'Ferrari', 74.274, 0.367, 32.0], ['Russell', 'Mercedes', 74.392, 0.485, 31.0], ['Bottas', 'Alfa Romeo', 74.448, 0.541, 32.0], ['Gasly', 'Alpine', 74.457, 0.55, 29.0], ['Hamilton', 'Mercedes', 74.549, 0.642, 31.0], ['Piastri', 'McLaren', 74.583, 0.676, 30.0], ['Zhou', 'Alfa Romeo', 74.585, 0.678, 29.0], ['Norris', 'McLaren', 74.694, 0.787, 30.0], ['Magnussen', 'Haas', 74.713, 0.806, 24.0], ['de', 'AlphaTauri', 74.785, 0.878, 33.0], ['Tsunoda', 'AlphaTauri', 74.84, 0.933, 34.0], ['Stroll', 'Aston Martin', 75.01, 1.103, 31.0], ['Albon', 'Williams', 75.056, 1.149, 32.0], ['Sargeant', 'Williams', 75.415, 1.508, 33.0]]
#
# [['Verstappen', 'Red Bull', 73.664, 0, 14.0], ['Pérez', 'Red Bull', 73.914, 0.25, 14.0], ['Hamilton', 'Mercedes', 74.072, 0.408, 9.0], ['Sainz', 'Ferrari', 74.24, 0.576, 20.0], ['Alonso', 'Aston Martin', 74.264, 0.6, 14.0], ['Russell', 'Mercedes', 74.278, 0.614, 16.0], ['Leclerc', 'Ferrari', 74.353, 0.689, 18.0], ['Bottas', 'Alfa Romeo', 74.36, 0.696, 15.0], ['Tsunoda', 'AlphaTauri', 74.659, 0.995, 16.0], ['Norris', 'McLaren', 74.681, 1.017, 20.0], ['Zhou', 'Alfa Romeo', 74.681, 1.017, 15.0], ['de', 'AlphaTauri', 74.693, 1.029, 18.0], ['Stroll', 'Aston Martin', 74.756, 1.092, 14.0], ['Hülkenberg', 'Haas', 74.988, 1.324, 12.0], ['Piastri', 'McLaren', 75.105, 1.441, 17.0], ['Ocon', 'Alpine', 75.266, 1.602, 15.0], ['Magnussen', 'Haas', 75.534, 1.87, 12.0], ['Gasly', 'Alpine', 75.841, 2.177, 14.0], ['Albon', 'Williams', 75.851, 2.187, 13.0], ['Sargeant', 'Williams', 76.529, 2.865, 5.0]]
#
#
# working on /races/2023-canadian-grand-prix
#
# [['Bottas', 'Alfa Romeo', 78.728, 0, 3.0], ['Stroll', 'Aston Martin', 79.175, 0.447, 3.0], ['Alonso', 'Aston Martin', 79.807, 1.079, 3.0], ['Pérez', 'Red Bull', 80.154, 1.426, 3.0], ['Verstappen', 'Red Bull', 80.231, 1.503, 3.0], ['Piastri', 'McLaren', 81.496, 2.768, 3.0], ['Magnussen', 'Haas', 84.045, 5.317, 3.0], ['Hülkenberg', 'Haas', 84.336, 5.608, 3.0], ['Zhou', 'Alfa Romeo', 84.961, 6.233, 3.0], ['Sainz', 'Ferrari', 85.991, 7.263, 3.0], ['Leclerc', 'Ferrari', 86.809, 8.081, 3.0], ['de', 'AlphaTauri', 92.274, 13.546, 3.0], ['Tsunoda', 'AlphaTauri', nan, 0, 2.0], ['Norris', 'McLaren', nan, 0, 2.0], ['Gasly', 'Alpine', nan, 0, 1.0], ['Albon', 'Williams', nan, 0, 1.0], ['Sargeant', 'Williams', nan, 0, 2.0]]
#
# [['Hamilton', 'Mercedes', 73.718, 0, 30.0], ['Russell', 'Mercedes', 73.745, 0.027, 31.0], ['Sainz', 'Ferrari', 73.844, 0.126, 39.0], ['Alonso', 'Aston Martin', 74.044, 0.326, 38.0], ['Leclerc', 'Ferrari', 74.094, 0.376, 38.0], ['Verstappen', 'Red Bull', 74.142, 0.424, 34.0], ['Bottas', 'Alfa Romeo', 74.22, 0.502, 40.0], ['Pérez', 'Red Bull', 74.25, 0.532, 29.0], ['Stroll', 'Aston Martin', 74.419, 0.701, 31.0], ['Gasly', 'Alpine', 74.477, 0.759, 39.0], ['Piastri', 'McLaren', 74.533, 0.815, 38.0], ['Magnussen', 'Haas', 74.544, 0.826, 36.0], ['Norris', 'McLaren', 74.617, 0.899, 40.0], ['Zhou', 'Alfa Romeo', 74.811, 1.093, 37.0], ['Tsunoda', 'AlphaTauri', 74.941, 1.223, 43.0], ['de', 'AlphaTauri', 75.002, 1.284, 38.0], ['Albon', 'Williams', 75.003, 1.285, 33.0], ['Ocon', 'Alpine', 75.092, 1.374, 17.0], ['Sargeant', 'Williams', 75.426, 1.708, 38.0], ['Hülkenberg', 'Haas', 76.369, 2.651, 11.0]]
#
# [['Verstappen', 'Red Bull', 83.106, 0, 22.0], ['Leclerc', 'Ferrari', 83.397, 0.291, 22.0], ['Alonso', 'Aston Martin', 84.483, 1.377, 18.0], ['Magnussen', 'Haas', 84.715, 1.609, 23.0], ['Sainz', 'Ferrari', 84.765, 1.659, 14.0], ['Gasly', 'Alpine', 84.825, 1.719, 19.0], ['Stroll', 'Aston Martin', 84.944, 1.838, 22.0], ['Tsunoda', 'AlphaTauri', 84.955, 1.849, 24.0], ['Bottas', 'Alfa Romeo', 84.988, 1.882, 22.0], ['Hamilton', 'Mercedes', 85.087, 1.981, 20.0], ['Hülkenberg', 'Haas', 85.14, 2.034, 20.0], ['Piastri', 'McLaren', 85.191, 2.085, 25.0], ['Norris', 'McLaren', 85.198, 2.092, 21.0], ['Albon', 'Williams', 85.379, 2.273, 21.0], ['Russell', 'Mercedes', 85.435, 2.329, 20.0], ['de', 'AlphaTauri', 85.725, 2.619, 24.0], ['Pérez', 'Red Bull', 85.857, 2.751, 20.0], ['Zhou', 'Alfa Romeo', 86.75, 3.644, 23.0], ['Ocon', 'Alpine', 86.84, 3.734, 10.0], ['Sargeant', 'Williams', 87.279, 4.173, 16.0]]
#
#
# working on /races/2023-austrian-grand-prix
#
# [['Verstappen', 'Red Bull', 65.742, 0, 30.0], ['Sainz', 'Ferrari', 65.983, 0.241, 32.0], ['Leclerc', 'Ferrari', 66.012, 0.27, 33.0], ['Hamilton', 'Mercedes', 66.251, 0.509, 34.0], ['Pérez', 'Red Bull', 66.262, 0.52, 32.0], ['Stroll', 'Aston Martin', 66.34, 0.598, 29.0], ['Magnussen', 'Haas', 66.497, 0.755, 27.0], ['Alonso', 'Aston Martin', 66.656, 0.914, 31.0], ['Russell', 'Mercedes', 66.696, 0.954, 28.0], ['Zhou', 'Alfa Romeo', 66.78, 1.038, 33.0], ['Albon', 'Williams', 66.794, 1.052, 23.0], ['Piastri', 'McLaren', 66.809, 1.067, 36.0], ['Hülkenberg', 'Haas', 66.846, 1.104, 30.0], ['Bottas', 'Alfa Romeo', 66.847, 1.105, 33.0], ['Tsunoda', 'AlphaTauri', 66.985, 1.243, 34.0], ['de', 'AlphaTauri', 67.017, 1.275, 36.0], ['Sargeant', 'Williams', 67.018, 1.276, 25.0], ['Ocon', 'Alpine', 67.202, 1.46, 30.0], ['Gasly', 'Alpine', 67.287, 1.545, 28.0], ['Norris', 'McLaren', 67.368, 1.626, 20.0]]
#
# FP2 does not exists
#
# FP3 does not exists
# working on /races/2023-british-grand-prix
#
# [['Verstappen', 'Red Bull', 88.6, 0, 26.0], ['Pérez', 'Red Bull', 89.048, 0.448, 22.0], ['Albon', 'Williams', 89.089, 0.489, 22.0], ['Alonso', 'Aston Martin', 89.268, 0.668, 21.0], ['Leclerc', 'Ferrari', 89.28, 0.68, 25.0], ['Ocon', 'Alpine', 89.319, 0.719, 23.0], ['Sainz', 'Ferrari', 89.357, 0.757, 25.0], ['Norris', 'McLaren', 89.441, 0.841, 25.0], ['Stroll', 'Aston Martin', 89.471, 0.871, 26.0], ['Piastri', 'McLaren', 89.658, 1.058, 16.0], ['de', 'AlphaTauri', 89.691, 1.091, 26.0], ['Hamilton', 'Mercedes', 89.768, 1.168, 23.0], ['Gasly', 'Alpine', 89.828, 1.228, 24.0], ['Russell', 'Mercedes', 89.874, 1.274, 28.0], ['Bottas', 'Alfa Romeo', 90.09, 1.49, 22.0], ['Tsunoda', 'AlphaTauri', 90.092, 1.492, 28.0], ['Sargeant', 'Williams', 90.124, 1.524, 24.0], ['Zhou', 'Alfa Romeo', 90.321, 1.721, 20.0], ['Magnussen', 'Haas', 90.385, 1.785, 21.0], ['Hülkenberg', 'Haas', 90.591, 1.991, 22.0]]
#
# [['Verstappen', 'Red Bull', 88.078, 0, 27.0], ['Sainz', 'Ferrari', 88.1, 0.022, 29.0], ['Albon', 'Williams', 88.296, 0.218, 30.0], ['Pérez', 'Red Bull', 88.342, 0.264, 30.0], ['Sargeant', 'Williams', 88.766, 0.688, 29.0], ['Stroll', 'Aston Martin', 88.866, 0.788, 30.0], ['Hülkenberg', 'Haas', 88.88, 0.802, 28.0], ['Gasly', 'Alpine', 88.889, 0.811, 27.0], ['Piastri', 'McLaren', 88.926, 0.848, 29.0], ['Alonso', 'Aston Martin', 89.134, 1.056, 26.0], ['Zhou', 'Alfa Romeo', 89.225, 1.147, 28.0], ['Russell', 'Mercedes', 89.238, 1.16, 25.0], ['Ocon', 'Alpine', 89.242, 1.164, 24.0], ['Norris', 'McLaren', 89.26, 1.182, 24.0], ['Hamilton', 'Mercedes', 89.283, 1.205, 24.0], ['Bottas', 'Alfa Romeo', 89.378, 1.3, 28.0], ['Magnussen', 'Haas', 89.439, 1.361, 20.0], ['Tsunoda', 'AlphaTauri', 89.483, 1.405, 25.0], ['de', 'AlphaTauri', 89.571, 1.493, 29.0]]
#
# [['Leclerc', 'Ferrari', 87.419, 0, 24.0], ['Albon', 'Williams', 87.592, 0.173, 14.0], ['Alonso', 'Aston Martin', 87.784, 0.365, 17.0], ['Gasly', 'Alpine', 87.893, 0.474, 19.0], ['Hamilton', 'Mercedes', 87.948, 0.529, 16.0], ['Sainz', 'Ferrari', 87.964, 0.545, 21.0], ['Sargeant', 'Williams', 88.151, 0.732, 16.0], ['Verstappen', 'Red Bull', 88.266, 0.847, 19.0], ['Russell', 'Mercedes', 88.284, 0.865, 17.0], ['Tsunoda', 'AlphaTauri', 88.337, 0.918, 21.0], ['de', 'AlphaTauri', 88.504, 1.085, 20.0], ['Norris', 'McLaren', 88.563, 1.144, 18.0], ['Stroll', 'Aston Martin', 88.62, 1.201, 15.0], ['Pérez', 'Red Bull', 88.904, 1.485, 19.0], ['Magnussen', 'Haas', 89.207, 1.788, 13.0], ['Ocon', 'Alpine', 89.233, 1.814, 22.0], ['Piastri', 'McLaren', 89.437, 2.018, 20.0], ['Bottas', 'Alfa Romeo', 89.586, 2.167, 15.0], ['Hülkenberg', 'Haas', 93.59, 6.171, 13.0], ['Zhou', 'Alfa Romeo', nan, 0, 2.0]]
#
#
# working on /races/2023-hungarian-grand-prix
#
# [['Russell', 'Mercedes', 98.795, 0, 13.0], ['Piastri', 'McLaren', 99.154, 0.359, 14.0], ['Stroll', 'Aston Martin', 100.013, 1.218, 10.0], ['Norris', 'McLaren', 100.277, 1.482, 13.0], ['Alonso', 'Aston Martin', 100.687, 1.892, 8.0], ['Bottas', 'Alfa Romeo', 101.032, 2.237, 14.0], ['Leclerc', 'Ferrari', 101.142, 2.347, 11.0], ['Zhou', 'Alfa Romeo', 101.363, 2.568, 9.0], ['Sargeant', 'Williams', 101.416, 2.621, 15.0], ['Hülkenberg', 'Haas', 102.706, 3.911, 12.0], ['Magnussen', 'Haas', 102.906, 4.111, 14.0], ['Tsunoda', 'AlphaTauri', 105.575, 6.78, 7.0], ['Albon', 'Williams', 107.403, 8.608, 10.0], ['Ricciardo', 'AlphaTauri', nan, 0, 7.0], ['Sainz', 'Ferrari', nan, 0, 6.0], ['Pérez', 'Red Bull', nan, 0, 2.0], ['Ocon', 'Alpine', nan, 0, 4.0], ['Gasly', 'Alpine', nan, 0, 3.0], ['Verstappen', 'Red Bull', nan, 0, 4.0], ['Hamilton', 'Mercedes', nan, 0, 3.0]]
#
# [['Leclerc', 'Ferrari', 77.686, 0, 20.0], ['Norris', 'McLaren', 77.701, 0.015, 30.0], ['Gasly', 'Alpine', 77.918, 0.232, 26.0], ['Tsunoda', 'AlphaTauri', 77.934, 0.248, 31.0], ['Ocon', 'Alpine', 78.045, 0.359, 30.0], ['Hülkenberg', 'Haas', 78.058, 0.372, 29.0], ['Bottas', 'Alfa Romeo', 78.085, 0.399, 29.0], ['Alonso', 'Aston Martin', 78.105, 0.419, 32.0], ['Zhou', 'Alfa Romeo', 78.108, 0.422, 31.0], ['Sainz', 'Ferrari', 78.182, 0.496, 20.0], ['Verstappen', 'Red Bull', 78.279, 0.593, 18.0], ['Stroll', 'Aston Martin', 78.319, 0.633, 33.0], ['Albon', 'Williams', 78.377, 0.691, 32.0], ['Ricciardo', 'AlphaTauri', 78.385, 0.699, 30.0], ['Magnussen', 'Haas', 78.504, 0.818, 27.0], ['Hamilton', 'Mercedes', 78.746, 1.06, 28.0], ['Sargeant', 'Williams', 78.836, 1.15, 30.0], ['Pérez', 'Red Bull', 78.978, 1.292, 14.0], ['Piastri', 'McLaren', 79.117, 1.431, 18.0], ['Russell', 'Mercedes', 79.175, 1.489, 23.0]]
#
# [['Hamilton', 'Mercedes', 77.811, 0, 20.0], ['Verstappen', 'Red Bull', 78.061, 0.25, 23.0], ['Pérez', 'Red Bull', 78.067, 0.256, 25.0], ['Hülkenberg', 'Haas', 78.077, 0.266, 21.0], ['Norris', 'McLaren', 78.082, 0.271, 19.0], ['Russell', 'Mercedes', 78.119, 0.308, 22.0], ['Leclerc', 'Ferrari', 78.19, 0.379, 28.0], ['Sainz', 'Ferrari', 78.234, 0.423, 29.0], ['Alonso', 'Aston Martin', 78.35, 0.539, 20.0], ['Bottas', 'Alfa Romeo', 78.489, 0.678, 24.0], ['Stroll', 'Aston Martin', 78.536, 0.725, 20.0], ['Zhou', 'Alfa Romeo', 78.544, 0.733, 23.0], ['Albon', 'Williams', 78.592, 0.781, 17.0], ['Piastri', 'McLaren', 78.598, 0.787, 19.0], ['Magnussen', 'Haas', 78.649, 0.838, 26.0], ['Gasly', 'Alpine', 78.776, 0.965, 22.0], ['Sargeant', 'Williams', 78.814, 1.003, 16.0], ['Ricciardo', 'AlphaTauri', 78.828, 1.017, 28.0], ['Ocon', 'Alpine', 78.979, 1.168, 22.0], ['Tsunoda', 'AlphaTauri', 79.156, 1.345, 29.0]]
#
#
# working on /races/2023-belgian-grand-prix
#
# [['Sainz', 'Ferrari', 123.207, 0, 9.0], ['Piastri', 'McLaren', 123.792, 0.585, 4.0], ['Norris', 'McLaren', 124.484, 1.277, 4.0], ['Leclerc', 'Ferrari', 128.148, 4.941, 8.0], ['Pérez', 'Red Bull', 128.24, 5.033, 5.0], ['Albon', 'Williams', 128.394, 5.187, 5.0], ['Tsunoda', 'AlphaTauri', 129.067, 5.86, 8.0], ['Magnussen', 'Haas', 129.229, 6.022, 7.0], ['Ricciardo', 'AlphaTauri', 129.319, 6.112, 7.0], ['Hülkenberg', 'Haas', 130.042, 6.835, 8.0], ['Alonso', 'Aston Martin', 130.283, 7.076, 4.0], ['Hamilton', 'Mercedes', 130.299, 7.092, 7.0], ['Russell', 'Mercedes', 130.475, 7.268, 7.0], ['Bottas', 'Alfa Romeo', 132.085, 8.878, 9.0], ['Zhou', 'Alfa Romeo', 134.002, 10.795, 8.0], ['Sargeant', 'Williams', nan, 0, 4.0], ['Stroll', 'Aston Martin', nan, 0, 5.0], ['Gasly', 'Alpine', nan, 0, 2.0], ['Ocon', 'Alpine', nan, 0, 2.0], ['Verstappen', 'Red Bull', nan, 0, 2.0]]
#
# FP2 does not exists
#
# FP3 does not exists
#
#
# working on /races/2023-dutch-grand-prix
#
# [['Verstappen', 'Red Bull', 71.852, 0, 31.0], ['Alonso', 'Aston Martin', 72.13, 0.278, 22.0], ['Hamilton', 'Mercedes', 72.225, 0.373, 24.0], ['Pérez', 'Red Bull', 72.323, 0.471, 27.0], ['Albon', 'Williams', 72.447, 0.595, 25.0], ['Norris', 'McLaren', 72.46, 0.608, 22.0], ['Sargeant', 'Williams', 72.617, 0.765, 30.0], ['Piastri', 'McLaren', 72.658, 0.806, 21.0], ['Tsunoda', 'AlphaTauri', 72.749, 0.897, 21.0], ['Ocon', 'Alpine', 72.802, 0.95, 29.0], ['Russell', 'Mercedes', 72.813, 0.961, 23.0], ['Gasly', 'Alpine', 72.895, 1.043, 30.0], ['Ricciardo', 'AlphaTauri', 72.99, 1.138, 26.0], ['Magnussen', 'Haas', 73.322, 1.47, 30.0], ['Bottas', 'Alfa Romeo', 73.448, 1.596, 30.0], ['Leclerc', 'Ferrari', 73.519, 1.667, 26.0], ['Zhou', 'Alfa Romeo', 73.826, 1.974, 20.0], ['Hülkenberg', 'Haas', 74.023, 2.171, 13.0], ['Shwartzman', 'Ferrari', 74.803, 2.951, 25.0], ['Stroll', 'Aston Martin', nan, 0, 2.0]]
#
# [['Norris', 'McLaren', 71.33, 0, 30.0], ['Verstappen', 'Red Bull', 71.353, 0.023, 26.0], ['Albon', 'Williams', 71.599, 0.269, 31.0], ['Hamilton', 'Mercedes', 71.638, 0.308, 27.0], ['Tsunoda', 'AlphaTauri', 71.72, 0.39, 31.0], ['Gasly', 'Alpine', 71.766, 0.436, 30.0], ['Pérez', 'Red Bull', 71.817, 0.487, 29.0], ['Stroll', 'Aston Martin', 71.835, 0.505, 31.0], ['Bottas', 'Alfa Romeo', 71.857, 0.527, 31.0], ['Alonso', 'Aston Martin', 71.863, 0.533, 31.0], ['Leclerc', 'Ferrari', 71.915, 0.585, 30.0], ['Sargeant', 'Williams', 71.934, 0.604, 32.0], ['Ocon', 'Alpine', 72.001, 0.671, 30.0], ['Russell', 'Mercedes', 72.009, 0.679, 28.0], ['Zhou', 'Alfa Romeo', 72.074, 0.744, 30.0], ['Sainz', 'Ferrari', 72.093, 0.763, 31.0], ['Magnussen', 'Haas', 72.404, 1.074, 28.0], ['Hülkenberg', 'Haas', 72.693, 1.363, 31.0], ['Piastri', 'McLaren', 72.901, 1.571, 6.0], ['Ricciardo', 'AlphaTauri', 73.096, 1.766, 7.0]]
#
# [['Verstappen', 'Red Bull', 81.631, 0, 18.0], ['Russell', 'Mercedes', 82.01, 0.379, 18.0], ['Pérez', 'Red Bull', 82.631, 1.0, 18.0], ['Alonso', 'Aston Martin', 82.634, 1.003, 14.0], ['Hamilton', 'Mercedes', 82.723, 1.092, 18.0], ['Albon', 'Williams', 82.75, 1.119, 19.0], ['Piastri', 'McLaren', 82.892, 1.261, 20.0], ['Bottas', 'Alfa Romeo', 82.965, 1.334, 25.0], ['Leclerc', 'Ferrari', 83.093, 1.462, 12.0], ['Norris', 'McLaren', 83.158, 1.527, 24.0], ['Gasly', 'Alpine', 83.21, 1.579, 15.0], ['Sainz', 'Ferrari', 83.438, 1.807, 17.0], ['Tsunoda', 'AlphaTauri', 83.544, 1.913, 18.0], ['Sargeant', 'Williams', 83.57, 1.939, 20.0], ['Hülkenberg', 'Haas', 83.64, 2.009, 20.0], ['Ocon', 'Alpine', 83.806, 2.175, 12.0], ['Stroll', 'Aston Martin', 84.058, 2.427, 15.0], ['Lawson', 'AlphaTauri', 86.343, 4.712, 26.0], ['Zhou', 'Alfa Romeo', 88.482, 6.851, 9.0], ['Magnussen', 'Haas', nan, 0, 1.0]]
# working on /races/2023-italian-grand-prix
#
# [['Verstappen', 'Red Bull', 82.657, 0, 31.0], ['Sainz', 'Ferrari', 82.703, 0.046, 28.0], ['Pérez', 'Red Bull', 82.834, 0.177, 30.0], ['Leclerc', 'Ferrari', 82.966, 0.309, 22.0], ['Russell', 'Mercedes', 83.189, 0.532, 28.0], ['Alonso', 'Aston Martin', 83.214, 0.557, 24.0], ['Norris', 'McLaren', 83.241, 0.584, 22.0], ['Hamilton', 'Mercedes', 83.269, 0.612, 26.0], ['Tsunoda', 'AlphaTauri', 83.271, 0.614, 23.0], ['Albon', 'Williams', 83.444, 0.787, 18.0], ['Piastri', 'McLaren', 83.446, 0.789, 24.0], ['Sargeant', 'Williams', 83.661, 1.004, 21.0], ['Lawson', 'AlphaTauri', 83.833, 1.176, 29.0], ['Gasly', 'Alpine', 83.931, 1.274, 26.0], ['Bottas', 'Alfa Romeo', 83.952, 1.295, 17.0], ['Hülkenberg', 'Haas', 84.067, 1.41, 23.0], ['Ocon', 'Alpine', 84.09, 1.433, 26.0], ['Drugovich', 'Aston Martin', 84.14, 1.483, 24.0], ['Magnussen', 'Haas', 84.217, 1.56, 24.0], ['Zhou', 'Alfa Romeo', 84.232, 1.575, 17.0]]
#
# [['Sainz', 'Ferrari', 81.355, 0, 23.0], ['Norris', 'McLaren', 81.374, 0.019, 20.0], ['Pérez', 'Red Bull', 81.54, 0.185, 17.0], ['Piastri', 'McLaren', 81.545, 0.19, 21.0], ['Verstappen', 'Red Bull', 81.631, 0.276, 20.0], ['Leclerc', 'Ferrari', 81.716, 0.361, 23.0], ['Albon', 'Williams', 81.979, 0.624, 19.0], ['Alonso', 'Aston Martin', 82.071, 0.716, 16.0], ['Russell', 'Mercedes', 82.176, 0.821, 20.0], ['Hülkenberg', 'Haas', 82.291, 0.936, 19.0], ['Magnussen', 'Haas', 82.574, 1.219, 21.0], ['Bottas', 'Alfa Romeo', 82.595, 1.24, 19.0], ['Gasly', 'Alpine', 82.651, 1.296, 22.0], ['Tsunoda', 'AlphaTauri', 82.696, 1.341, 23.0], ['Ocon', 'Alpine', 82.716, 1.361, 22.0], ['Sargeant', 'Williams', 82.755, 1.4, 24.0], ['Hamilton', 'Mercedes', 82.783, 1.428, 23.0], ['Lawson', 'AlphaTauri', 83.167, 1.812, 23.0], ['Zhou', 'Alfa Romeo', 83.346, 1.991, 20.0], ['Stroll', 'Aston Martin', nan, 0, 2.0]]
#
# [['Sainz', 'Ferrari', 80.912, 0, 23.0], ['Verstappen', 'Red Bull', 80.998, 0.086, 23.0], ['Hamilton', 'Mercedes', 81.453, 0.541, 23.0], ['Leclerc', 'Ferrari', 81.486, 0.574, 23.0], ['Alonso', 'Aston Martin', 81.711, 0.799, 24.0], ['Russell', 'Mercedes', 81.73, 0.818, 25.0], ['Magnussen', 'Haas', 81.884, 0.972, 21.0], ['Hülkenberg', 'Haas', 81.985, 1.073, 27.0], ['Albon', 'Williams', 82.054, 1.142, 18.0], ['Pérez', 'Red Bull', 82.192, 1.28, 16.0], ['Stroll', 'Aston Martin', 82.245, 1.333, 31.0], ['Lawson', 'AlphaTauri', 82.296, 1.384, 29.0], ['Tsunoda', 'AlphaTauri', 82.297, 1.385, 28.0], ['Piastri', 'McLaren', 82.302, 1.39, 17.0], ['Sargeant', 'Williams', 82.38, 1.468, 23.0], ['Bottas', 'Alfa Romeo', 82.511, 1.599, 30.0], ['Norris', 'McLaren', 82.515, 1.603, 24.0], ['Ocon', 'Alpine', 82.739, 1.827, 20.0], ['Zhou', 'Alfa Romeo', 82.742, 1.83, 30.0], ['Gasly', 'Alpine', 82.852, 1.94, 22.0]]
#
#
# working on /races/2023-singapore-grand-prix
#
# [['Leclerc', 'Ferrari', 93.35, 0, 25.0], ['Sainz', 'Ferrari', 93.428, 0.078, 24.0], ['Verstappen', 'Red Bull', 93.476, 0.126, 22.0], ['Norris', 'McLaren', 93.522, 0.172, 24.0], ['Hamilton', 'Mercedes', 93.54, 0.19, 21.0], ['Russell', 'Mercedes', 93.695, 0.345, 25.0], ['Pérez', 'Red Bull', 93.725, 0.375, 22.0], ['Alonso', 'Aston Martin', 93.974, 0.624, 28.0], ['Tsunoda', 'AlphaTauri', 94.042, 0.692, 25.0], ['Ocon', 'Alpine', 94.066, 0.716, 24.0], ['Stroll', 'Aston Martin', 94.568, 1.218, 25.0], ['Gasly', 'Alpine', 94.639, 1.289, 23.0], ['Albon', 'Williams', 94.657, 1.307, 19.0], ['Bottas', 'Alfa Romeo', 94.802, 1.452, 25.0], ['Magnussen', 'Haas', 94.887, 1.537, 23.0], ['Lawson', 'AlphaTauri', 94.894, 1.544, 27.0], ['Hülkenberg', 'Haas', 94.985, 1.635, 22.0], ['Zhou', 'Alfa Romeo', 95.456, 2.106, 25.0], ['Piastri', 'McLaren', 95.474, 2.124, 22.0], ['Sargeant', 'Williams', 95.778, 2.428, 24.0]]
#
# [['Sainz', 'Ferrari', 92.12, 0, 26.0], ['Leclerc', 'Ferrari', 92.138, 0.018, 27.0], ['Russell', 'Mercedes', 92.355, 0.235, 25.0], ['Alonso', 'Aston Martin', 92.478, 0.358, 25.0], ['Hamilton', 'Mercedes', 92.585, 0.465, 23.0], ['Norris', 'McLaren', 92.711, 0.591, 23.0], ['Pérez', 'Red Bull', 92.812, 0.692, 23.0], ['Verstappen', 'Red Bull', 92.852, 0.732, 23.0], ['Magnussen', 'Haas', 93.017, 0.897, 25.0], ['Bottas', 'Alfa Romeo', 93.105, 0.985, 24.0], ['Hülkenberg', 'Haas', 93.139, 1.019, 22.0], ['Lawson', 'AlphaTauri', 93.285, 1.165, 27.0], ['Ocon', 'Alpine', 93.361, 1.241, 25.0], ['Stroll', 'Aston Martin', 93.39, 1.27, 25.0], ['Piastri', 'McLaren', 93.461, 1.341, 23.0], ['Tsunoda', 'AlphaTauri', 93.477, 1.357, 27.0], ['Zhou', 'Alfa Romeo', 93.575, 1.455, 25.0], ['Gasly', 'Alpine', 93.824, 1.704, 24.0], ['Sargeant', 'Williams', 94.327, 2.207, 28.0], ['Albon', 'Williams', 95.558, 3.438, 5.0]]
#
# [['Sainz', 'Ferrari', 92.065, 0, 23.0], ['Russell', 'Mercedes', 92.134, 0.069, 20.0], ['Norris', 'McLaren', 92.303, 0.238, 17.0], ['Verstappen', 'Red Bull', 92.378, 0.313, 21.0], ['Leclerc', 'Ferrari', 92.381, 0.316, 25.0], ['Hamilton', 'Mercedes', 92.535, 0.47, 18.0], ['Piastri', 'McLaren', 92.73, 0.665, 18.0], ['Pérez', 'Red Bull', 92.784, 0.719, 20.0], ['Hülkenberg', 'Haas', 92.896, 0.831, 18.0], ['Tsunoda', 'AlphaTauri', 92.945, 0.88, 18.0], ['Magnussen', 'Haas', 92.97, 0.905, 16.0], ['Ocon', 'Alpine', 92.979, 0.914, 19.0], ['Alonso', 'Aston Martin', 93.051, 0.986, 19.0], ['Stroll', 'Aston Martin', 93.126, 1.061, 23.0], ['Gasly', 'Alpine', 93.351, 1.286, 19.0], ['Lawson', 'AlphaTauri', 93.357, 1.292, 19.0], ['Albon', 'Williams', 93.37, 1.305, 15.0], ['Bottas', 'Alfa Romeo', 93.54, 1.475, 26.0], ['Zhou', 'Alfa Romeo', 93.637, 1.572, 24.0], ['Sargeant', 'Williams', 93.708, 1.643, 16.0]]
#
#
# working on /races/2023-japanese-grand-prix
#
# [['Verstappen', 'Red Bull', 91.647, 0, 25.0], ['Sainz', 'Ferrari', 92.273, 0.626, 24.0], ['Norris', 'McLaren', 92.392, 0.745, 24.0], ['Leclerc', 'Ferrari', 92.574, 0.927, 25.0], ['Tsunoda', 'AlphaTauri', 92.597, 0.95, 21.0], ['Alonso', 'Aston Martin', 92.65, 1.003, 23.0], ['Piastri', 'McLaren', 92.713, 1.066, 26.0], ['Albon', 'Williams', 92.991, 1.344, 24.0], ['Lawson', 'AlphaTauri', 93.005, 1.358, 28.0], ['Stroll', 'Aston Martin', 93.04, 1.393, 17.0], ['Pérez', 'Red Bull', 93.043, 1.396, 25.0], ['Gasly', 'Alpine', 93.129, 1.482, 23.0], ['Russell', 'Mercedes', 93.31, 1.663, 24.0], ['Hülkenberg', 'Haas', 93.448, 1.801, 24.0], ['Ocon', 'Alpine', 93.516, 1.869, 22.0], ['Hamilton', 'Mercedes', 93.699, 2.052, 22.0], ['Bottas', 'Alfa Romeo', 93.86, 2.213, 24.0], ['Magnussen', 'Haas', 93.975, 2.328, 23.0], ['Sargeant', 'Williams', 94.212, 2.565, 27.0], ['Zhou', 'Alfa Romeo', 94.831, 3.184, 23.0]]
#
# [['Verstappen', 'Red Bull', 90.688, 0, 19.0], ['Leclerc', 'Ferrari', 91.008, 0.32, 23.0], ['Norris', 'McLaren', 91.152, 0.464, 22.0], ['Sainz', 'Ferrari', 91.237, 0.549, 22.0], ['Russell', 'Mercedes', 91.328, 0.64, 22.0], ['Alonso', 'Aston Martin', 91.492, 0.804, 22.0], ['Albon', 'Williams', 91.555, 0.867, 23.0], ['Piastri', 'McLaren', 91.662, 0.974, 22.0], ['Pérez', 'Red Bull', 91.71, 1.022, 24.0], ['Bottas', 'Alfa Romeo', 91.739, 1.051, 22.0], ['Stroll', 'Aston Martin', 91.771, 1.083, 22.0], ['Ocon', 'Alpine', 91.794, 1.106, 22.0], ['Hülkenberg', 'Haas', 91.797, 1.109, 24.0], ['Hamilton', 'Mercedes', 91.829, 1.141, 21.0], ['Lawson', 'AlphaTauri', 92.141, 1.453, 23.0], ['Zhou', 'Alfa Romeo', 92.165, 1.477, 16.0], ['Magnussen', 'Haas', 92.169, 1.481, 23.0], ['Tsunoda', 'AlphaTauri', 92.178, 1.49, 26.0], ['Gasly', 'Alpine', 92.179, 1.491, 22.0], ['Sargeant', 'Williams', 92.32, 1.632, 25.0]]
#
# [['Verstappen', 'Red Bull', 90.267, 0, 12.0], ['Norris', 'McLaren', 90.507, 0.24, 16.0], ['Piastri', 'McLaren', 90.555, 0.288, 15.0], ['Pérez', 'Red Bull', 91.004, 0.737, 12.0], ['Leclerc', 'Ferrari', 91.022, 0.755, 20.0], ['Sainz', 'Ferrari', 91.137, 0.87, 20.0], ['Hamilton', 'Mercedes', 91.159, 0.892, 13.0], ['Russell', 'Mercedes', 91.505, 1.238, 9.0], ['Alonso', 'Aston Martin', 91.549, 1.282, 16.0], ['Zhou', 'Alfa Romeo', 91.668, 1.401, 15.0], ['Bottas', 'Alfa Romeo', 91.699, 1.432, 15.0], ['Magnussen', 'Haas', 91.88, 1.613, 16.0], ['Ocon', 'Alpine', 91.924, 1.657, 13.0], ['Tsunoda', 'AlphaTauri', 91.951, 1.684, 18.0], ['Hülkenberg', 'Haas', 91.979, 1.712, 13.0], ['Sargeant', 'Williams', 92.002, 1.735, 13.0], ['Lawson', 'AlphaTauri', 92.048, 1.781, 18.0], ['Albon', 'Williams', 92.113, 1.846, 12.0], ['Stroll', 'Aston Martin', 92.154, 1.887, 19.0], ['Gasly', 'Alpine', 92.199, 1.932, 15.0]]
# working on /races/2023-qatar-grand-prix
#
# [['Verstappen', 'Red Bull', 87.428, 0, 26.0], ['Sainz', 'Ferrari', 87.762, 0.334, 27.0], ['Leclerc', 'Ferrari', 87.909, 0.481, 27.0], ['Alonso', 'Aston Martin', 87.919, 0.491, 28.0], ['Pérez', 'Red Bull', 88.016, 0.588, 24.0], ['Tsunoda', 'AlphaTauri', 88.027, 0.599, 28.0], ['Hülkenberg', 'Haas', 88.171, 0.743, 22.0], ['Russell', 'Mercedes', 88.336, 0.908, 28.0], ['Piastri', 'McLaren', 88.38, 0.952, 20.0], ['Norris', 'McLaren', 88.441, 1.013, 24.0], ['Sargeant', 'Williams', 88.55, 1.122, 25.0], ['Albon', 'Williams', 88.59, 1.162, 26.0], ['Hamilton', 'Mercedes', 88.679, 1.251, 26.0], ['Stroll', 'Aston Martin', 88.69, 1.262, 28.0], ['Ocon', 'Alpine', 88.732, 1.304, 25.0], ['Gasly', 'Alpine', 88.821, 1.393, 23.0], ['Bottas', 'Alfa Romeo', 89.041, 1.613, 27.0], ['Zhou', 'Alfa Romeo', 89.106, 1.678, 29.0], ['Lawson', 'AlphaTauri', 89.238, 1.81, 29.0], ['Magnussen', 'Haas', 89.502, 2.074, 26.0]]
#
# FP2 does not exists
#
# FP3 does not exists
#
#
# working on /races/2023-united-states-grand-prix
#
# [['Verstappen', 'Red Bull', 95.912, 0, 23.0], ['Leclerc', 'Ferrari', 96.068, 0.156, 25.0], ['Hamilton', 'Mercedes', 96.193, 0.281, 23.0], ['Pérez', 'Red Bull', 96.212, 0.3, 23.0], ['Magnussen', 'Haas', 96.472, 0.56, 21.0], ['Russell', 'Mercedes', 96.474, 0.562, 25.0], ['Albon', 'Williams', 96.492, 0.58, 21.0], ['Sainz', 'Ferrari', 96.533, 0.621, 24.0], ['Hülkenberg', 'Haas', 96.702, 0.79, 21.0], ['Gasly', 'Alpine', 96.705, 0.793, 22.0], ['Sargeant', 'Williams', 96.987, 1.075, 26.0], ['Ocon', 'Alpine', 97.066, 1.154, 22.0], ['Tsunoda', 'AlphaTauri', 97.104, 1.192, 25.0], ['Ricciardo', 'AlphaTauri', 97.152, 1.24, 24.0], ['Norris', 'McLaren', 97.256, 1.344, 21.0], ['Zhou', 'Alfa Romeo', 97.418, 1.506, 25.0], ['Bottas', 'Alfa Romeo', 97.517, 1.605, 24.0], ['Alonso', 'Aston Martin', 97.84, 1.928, 19.0], ['Piastri', 'McLaren', 98.42, 2.508, 22.0], ['Stroll', 'Aston Martin', 99.94, 4.028, 5.0]]
#
# FP2 does not exists
#
# FP3 does not exists
#
#
# working on /races/2023-mexican-grand-prix
#
# [['Verstappen', 'Red Bull', 79.718, 0, 29.0], ['Albon', 'Williams', 79.813, 0.095, 31.0], ['Pérez', 'Red Bull', 80.015, 0.297, 28.0], ['Norris', 'McLaren', 80.237, 0.519, 30.0], ['Leclerc', 'Ferrari', 80.297, 0.579, 30.0], ['Piastri', 'McLaren', 80.463, 0.745, 32.0], ['Sainz', 'Ferrari', 80.479, 0.761, 23.0], ['Ricciardo', 'AlphaTauri', 80.568, 0.85, 30.0], ['Ocon', 'Alpine', 80.677, 0.959, 26.0], ['Stroll', 'Aston Martin', 80.687, 0.969, 26.0], ['Hamilton', 'Mercedes', 80.724, 1.006, 25.0], ['Hülkenberg', 'Haas', 80.968, 1.25, 29.0], ['Zhou', 'Alfa Romeo', 81.129, 1.411, 27.0], ['Sargeant', 'Williams', 81.157, 1.439, 30.0], ['Bearman', 'Haas', 81.313, 1.595, 31.0], ['Alonso', 'Aston Martin', 81.347, 1.629, 17.0], ['Hadjar', 'AlphaTauri', 81.941, 2.223, 25.0], ['Doohan', 'Alpine', 82.109, 2.391, 25.0], ['Vesti', 'Mercedes', 82.937, 3.219, 26.0], ['Pourchaire', 'Alfa Romeo', nan, 0, 4.0]]
#
# [['Verstappen', 'Red Bull', 78.686, 0, 26.0], ['Norris', 'McLaren', 78.805, 0.119, 31.0], ['Leclerc', 'Ferrari', 78.952, 0.266, 33.0], ['Bottas', 'Alfa Romeo', 78.955, 0.269, 33.0], ['Pérez', 'Red Bull', 78.988, 0.302, 29.0], ['Ricciardo', 'AlphaTauri', 79.002, 0.316, 31.0], ['Hamilton', 'Mercedes', 79.024, 0.338, 30.0], ['Ocon', 'Alpine', 79.077, 0.391, 29.0], ['Piastri', 'McLaren', 79.163, 0.477, 31.0], ['Russell', 'Mercedes', 79.227, 0.541, 31.0], ['Sainz', 'Ferrari', 79.257, 0.571, 34.0], ['Tsunoda', 'AlphaTauri', 79.29, 0.604, 34.0], ['Zhou', 'Alfa Romeo', 79.415, 0.729, 27.0], ['Albon', 'Williams', 79.446, 0.76, 23.0], ['Hülkenberg', 'Haas', 79.535, 0.849, 29.0], ['Gasly', 'Alpine', 79.642, 0.956, 29.0], ['Sargeant', 'Williams', 79.9, 1.214, 26.0], ['Stroll', 'Aston Martin', 80.075, 1.389, 17.0], ['Magnussen', 'Haas', 80.112, 1.426, 30.0], ['Alonso', 'Aston Martin', 80.426, 1.74, 30.0]]
#
# [['Verstappen', 'Red Bull', 77.887, 0, 19.0], ['Albon', 'Williams', 77.957, 0.07, 19.0], ['Pérez', 'Red Bull', 78.026, 0.139, 19.0], ['Russell', 'Mercedes', 78.248, 0.361, 20.0], ['Piastri', 'McLaren', 78.392, 0.505, 22.0], ['Bottas', 'Alfa Romeo', 78.437, 0.55, 26.0], ['Tsunoda', 'AlphaTauri', 78.45, 0.563, 26.0], ['Norris', 'McLaren', 78.48, 0.593, 21.0], ['Ricciardo', 'AlphaTauri', 78.499, 0.612, 15.0], ['Hamilton', 'Mercedes', 78.522, 0.635, 21.0], ['Sargeant', 'Williams', 78.718, 0.831, 15.0], ['Zhou', 'Alfa Romeo', 78.917, 1.03, 21.0], ['Leclerc', 'Ferrari', 78.97, 1.083, 22.0], ['Stroll', 'Aston Martin', 79.094, 1.207, 21.0], ['Sainz', 'Ferrari', 79.293, 1.406, 23.0], ['Hülkenberg', 'Haas', 79.32, 1.433, 18.0], ['Alonso', 'Aston Martin', 79.471, 1.584, 21.0], ['Gasly', 'Alpine', 79.509, 1.622, 19.0], ['Magnussen', 'Haas', 79.573, 1.686, 9.0], ['Ocon', 'Alpine', 79.839, 1.952, 19.0]]
#
#
# working on /races/2023-brazilian-grand-prix
#
# [['Sainz', 'Ferrari', 71.732, 0, 30.0], ['Leclerc', 'Ferrari', 71.84, 0.108, 32.0], ['Russell', 'Mercedes', 71.865, 0.133, 31.0], ['Hülkenberg', 'Haas', 71.928, 0.196, 19.0], ['Albon', 'Williams', 72.044, 0.312, 28.0], ['Stroll', 'Aston Martin', 72.136, 0.404, 26.0], ['Gasly', 'Alpine', 72.184, 0.452, 31.0], ['Zhou', 'Alfa Romeo', 72.481, 0.749, 27.0], ['Sargeant', 'Williams', 72.579, 0.847, 30.0], ['Magnussen', 'Haas', 72.592, 0.86, 24.0], ['Alonso', 'Aston Martin', 72.615, 0.883, 28.0], ['Hamilton', 'Mercedes', 72.638, 0.906, 30.0], ['Tsunoda', 'AlphaTauri', 72.714, 0.982, 29.0], ['Ricciardo', 'AlphaTauri', 72.778, 1.046, 27.0], ['Ocon', 'Alpine', 72.779, 1.047, 30.0], ['Verstappen', 'Red Bull', 72.793, 1.061, 30.0], ['Bottas', 'Alfa Romeo', 73.012, 1.28, 31.0], ['Pérez', 'Red Bull', 73.056, 1.324, 31.0], ['Norris', 'McLaren', 73.629, 1.897, 25.0], ['Piastri', 'McLaren', 73.838, 2.106, 28.0]]
#
# FP2 does not exists
#
# FP3 does not exists
#
#
# working on /races/2023-las-vegas-grand-prix
#
# [['Leclerc', 'Ferrari', 100.909, 0, 4.0], ['Hülkenberg', 'Haas', 103.446, 2.537, 4.0], ['Magnussen', 'Haas', 104.261, 3.352, 4.0], ['Verstappen', 'Red Bull', 104.397, 3.488, 4.0], ['Ocon', 'Alpine', 105.365, 4.456, 5.0], ['Russell', 'Mercedes', 105.497, 4.588, 4.0], ['Sainz', 'Ferrari', 105.824, 4.915, 4.0], ['Tsunoda', 'AlphaTauri', 105.908, 4.999, 5.0], ['Pérez', 'Red Bull', 106.793, 5.884, 4.0], ['Bottas', 'Alfa Romeo', 107.147, 6.238, 5.0], ['Gasly', 'Alpine', 108.253, 7.344, 5.0], ['Hamilton', 'Mercedes', 108.513, 7.604, 4.0], ['Ricciardo', 'AlphaTauri', 108.65, 7.741, 4.0], ['Zhou', 'Alfa Romeo', 108.822, 7.913, 5.0], ['Norris', 'McLaren', 108.947, 8.038, 3.0], ['Stroll', 'Aston Martin', nan, 0, 2.0], ['Piastri', 'McLaren', nan, 0, 2.0], ['Albon', 'Williams', nan, 0, 2.0], ['Alonso', 'Aston Martin', nan, 0, 2.0]]
#
# [['Leclerc', 'Ferrari', 95.265, 0, 39.0], ['Sainz', 'Ferrari', 95.782, 0.517, 39.0], ['Alonso', 'Aston Martin', 95.793, 0.528, 38.0], ['Pérez', 'Red Bull', 96.085, 0.82, 36.0], ['Bottas', 'Alfa Romeo', 96.129, 0.864, 36.0], ['Verstappen', 'Red Bull', 96.183, 0.918, 37.0], ['Hülkenberg', 'Haas', 96.489, 1.224, 33.0], ['Stroll', 'Aston Martin', 96.496, 1.231, 41.0], ['Hamilton', 'Mercedes', 96.663, 1.398, 42.0], ['Albon', 'Williams', 96.688, 1.423, 42.0], ['Norris', 'McLaren', 96.864, 1.599, 33.0], ['Russell', 'Mercedes', 96.89, 1.625, 37.0], ['Magnussen', 'Haas', 96.917, 1.652, 37.0], ['Piastri', 'McLaren', 96.987, 1.722, 35.0], ['Gasly', 'Alpine', 97.134, 1.869, 33.0], ['Ocon', 'Alpine', 97.241, 1.976, 37.0], ['Tsunoda', 'AlphaTauri', 97.412, 2.147, 41.0], ['Zhou', 'Alfa Romeo', 97.656, 2.391, 36.0], ['Ricciardo', 'AlphaTauri', 97.68, 2.415, 40.0], ['Sargeant', 'Williams', 98.14, 2.875, 42.0]]
#
# [['Russell', 'Mercedes', 94.093, 0, 23.0], ['Piastri', 'McLaren', 94.491, 0.398, 20.0], ['Sargeant', 'Williams', 94.645, 0.552, 17.0], ['Verstappen', 'Red Bull', 94.653, 0.56, 14.0], ['Pérez', 'Red Bull', 94.706, 0.613, 13.0], ['Albon', 'Williams', 94.726, 0.633, 14.0], ['Alonso', 'Aston Martin', 94.788, 0.695, 18.0], ['Hamilton', 'Mercedes', 94.853, 0.76, 24.0], ['Bottas', 'Alfa Romeo', 94.908, 0.815, 18.0], ['Magnussen', 'Haas', 95.067, 0.974, 18.0], ['Norris', 'McLaren', 95.089, 0.996, 17.0], ['Hülkenberg', 'Haas', 95.112, 1.019, 17.0], ['Stroll', 'Aston Martin', 95.253, 1.16, 20.0], ['Ocon', 'Alpine', 95.297, 1.204, 15.0], ['Zhou', 'Alfa Romeo', 95.881, 1.788, 15.0], ['Leclerc', 'Ferrari', 95.908, 1.815, 22.0], ['Sainz', 'Ferrari', 95.939, 1.846, 21.0], ['Tsunoda', 'AlphaTauri', 96.087, 1.994, 15.0], ['Gasly', 'Alpine', 96.485, 2.392, 12.0], ['Ricciardo', 'AlphaTauri', 97.778, 3.685, 15.0]]
# working on /races/2023-abu-dhabi-grand-prix
#
# ...
#
# [['Hamilton', 'Mercedes', 107.49, 0, 25.0], ['Alonso', 'Ferrari', 107.623, 0.133, 28.0], ['Ricciardo', 'Red Bull', 107.79, 0.3, 28.0], ['Räikkönen', 'Ferrari', 108.031, 0.541, 29.0], ['Vettel', 'Red Bull', 108.041, 0.551, 5.0], ['Magnussen', 'McLaren', 108.358, 0.868, 33.0], ['Button', 'McLaren', 108.435, 0.945, 30.0], ['Pérez', 'Force India', 108.653, 1.163, 30.0], ['Hülkenberg', 'Force India', 108.751, 1.261, 31.0], ['Kvyat', 'Toro Rosso', 108.77, 1.28, 31.0], ['Vergne', 'Toro Rosso', 108.8, 1.31, 33.0], ['Grosjean', 'Lotus', 109.062, 1.572, 33.0], ['Rosberg', 'Mercedes', 109.075, 1.585, 30.0], ['Maldonado', 'Lotus', 109.139, 1.649, 13.0], ['Sutil', 'Sauber', 109.17, 1.68, 34.0], ['Gutiérrez', 'Sauber', 109.29, 1.8, 37.0], ['Massa', 'Williams', 109.361, 1.871, 29.0], ['Bottas', 'Williams', 109.971, 2.481, 28.0], ['Bianchi', 'Marussia', 110.612, 3.122, 24.0], ['Chilton', 'Marussia', 111.558, 4.068, 21.0], ['Kobayashi', 'Caterham', 112.075, 4.585, 33.0], ['Ericsson', 'Caterham', 112.936, 5.446, 31.0]]
#
# [['Alonso', 'Ferrari', 107.299, 0, 12.0], ['Ricciardo', 'Red Bull', 107.35, 0.051, 15.0], ['Rosberg', 'Mercedes', 107.488, 0.189, 15.0], ['Vergne', 'Toro Rosso', 107.693, 0.394, 17.0], ['Vettel', 'Red Bull', 107.711, 0.412, 17.0], ['Hamilton', 'Mercedes', 107.738, 0.439, 12.0], ['Massa', 'Williams', 107.909, 0.61, 15.0], ['Bottas', 'Williams', 108.205, 0.906, 15.0], ['Räikkönen', 'Ferrari', 108.226, 0.927, 16.0], ['Gutiérrez', 'Sauber', 108.422, 1.123, 20.0], ['Hülkenberg', 'Force India', 108.45, 1.151, 11.0], ['Magnussen', 'McLaren', 108.577, 1.278, 9.0], ['Button', 'McLaren', 108.599, 1.3, 16.0], ['Kvyat', 'Toro Rosso', 108.637, 1.338, 18.0], ['Pérez', 'Force India', 109.078, 1.779, 15.0], ['Sutil', 'Sauber', 109.115, 1.816, 19.0], ['Grosjean', 'Lotus', 109.485, 2.186, 17.0], ['Maldonado', 'Lotus', 110.149, 2.85, 15.0], ['Bianchi', 'Marussia', 110.376, 3.077, 17.0], ['Kobayashi', 'Caterham', 110.939, 3.64, 17.0], ['Chilton', 'Marussia', 111.221, 3.922, 16.0], ['Ericsson', 'Caterham', 111.598, 4.299, 17.0]]
#
#
# working on /races/2014-japanese-grand-prix
#
# [['Rosberg', 'Mercedes', 95.461, 0, 27.0], ['Hamilton', 'Mercedes', 95.612, 0.151, 26.0], ['Alonso', 'Ferrari', 96.037, 0.576, 19.0], ['Bottas', 'Williams', 96.576, 1.115, 25.0], ['Räikkönen', 'Ferrari', 97.187, 1.726, 19.0], ['Magnussen', 'McLaren', 97.327, 1.866, 24.0], ['Ricciardo', 'Red Bull', 97.466, 2.005, 27.0], ['Button', 'McLaren', 97.649, 2.188, 24.0], ['Vettel', 'Red Bull', 97.686, 2.225, 26.0], ['Kvyat', 'Toro Rosso', 97.714, 2.253, 26.0], ['Massa', 'Williams', 98.012, 2.551, 22.0], ['Verstappen', 'Toro Rosso', 98.157, 2.696, 22.0], ['Pérez', 'Force India', 98.324, 2.863, 10.0], ['Hülkenberg', 'Force India', 98.582, 3.121, 9.0], ['Grosjean', 'Lotus', 98.851, 3.39, 21.0], ['Sutil', 'Sauber', 99.046, 3.585, 19.0], ['Maldonado', 'Lotus', 99.097, 3.636, 26.0], ['Gutiérrez', 'Sauber', 99.318, 3.857, 18.0], ['Ericsson', 'Caterham', 100.031, 4.57, 18.0], ['Merhi', 'Caterham', 101.472, 6.011, 24.0], ['Bianchi', 'Marussia', 101.58, 6.119, 10.0], ['Chilton', 'Marussia', 101.757, 6.296, 15.0]]
#
# [['Hamilton', 'Mercedes', 95.078, 0, 28.0], ['Rosberg', 'Mercedes', 95.318, 0.24, 27.0], ['Bottas', 'Williams', 96.279, 1.201, 24.0], ['Button', 'McLaren', 96.409, 1.331, 28.0], ['Vettel', 'Red Bull', 96.436, 1.358, 24.0], ['Räikkönen', 'Ferrari', 96.529, 1.451, 19.0], ['Alonso', 'Ferrari', 96.637, 1.559, 26.0], ['Magnussen', 'McLaren', 96.714, 1.636, 31.0], ['Kvyat', 'Toro Rosso', 96.943, 1.865, 27.0], ['Ricciardo', 'Red Bull', 97.186, 2.108, 3.0], ['Vergne', 'Toro Rosso', 97.219, 2.141, 19.0], ['Hülkenberg', 'Force India', 97.504, 2.426, 16.0], ['Grosjean', 'Lotus', 97.563, 2.485, 31.0], ['Massa', 'Williams', 97.7, 2.622, 18.0], ['Pérez', 'Force India', 97.786, 2.708, 8.0], ['Maldonado', 'Lotus', 97.798, 2.72, 27.0], ['Sutil', 'Sauber', 98.01, 2.932, 25.0], ['Gutiérrez', 'Sauber', 98.365, 3.287, 9.0], ['Ericsson', 'Caterham', 99.069, 3.991, 22.0], ['Bianchi', 'Marussia', 99.306, 4.228, 20.0], ['Chilton', 'Marussia', 99.333, 4.255, 24.0], ['Kobayashi', 'Caterham', 102.76, 7.682, 3.0]]
#
# [['Rosberg', 'Mercedes', 93.228, 0, 14.0], ['Hamilton', 'Mercedes', 94.21, 0.982, 10.0], ['Alonso', 'Ferrari', 94.439, 1.211, 12.0], ['Massa', 'Williams', 94.564, 1.336, 12.0], ['Bottas', 'Williams', 95.061, 1.833, 16.0], ['Ricciardo', 'Red Bull', 95.086, 1.858, 13.0], ['Magnussen', 'McLaren', 95.251, 2.023, 16.0], ['Vergne', 'Toro Rosso', 95.494, 2.266, 8.0], ['Kvyat', 'Toro Rosso', 95.538, 2.31, 17.0], ['Button', 'McLaren', 95.549, 2.321, 16.0], ['Hülkenberg', 'Force India', 95.732, 2.504, 15.0], ['Räikkönen', 'Ferrari', 95.995, 2.767, 5.0], ['Pérez', 'Force India', 96.365, 3.137, 8.0], ['Gutiérrez', 'Sauber', 96.407, 3.179, 22.0], ['Vettel', 'Red Bull', 96.46, 3.232, 6.0], ['Grosjean', 'Lotus', 96.558, 3.33, 19.0], ['Maldonado', 'Lotus', 96.617, 3.389, 12.0], ['Sutil', 'Sauber', 96.626, 3.398, 20.0], ['Ericsson', 'Caterham', 97.367, 4.139, 12.0], ['Chilton', 'Marussia', 97.883, 4.655, 17.0], ['Bianchi', 'Marussia', 98.102, 4.874, 15.0], ['Kobayashi', 'Caterham', 98.784, 5.556, 12.0]]
#
#
# working on /races/2014-russian-grand-prix
#
# [['Rosberg', 'Mercedes', 102.311, 0, 29.0], ['Hamilton', 'Mercedes', 102.376, 0.065, 25.0], ['Button', 'McLaren', 102.507, 0.196, 28.0], ['Alonso', 'Ferrari', 102.72, 0.409, 27.0], ['Magnussen', 'McLaren', 103.026, 0.715, 28.0], ['Pérez', 'Force India', 103.129, 0.818, 26.0], ['Kvyat', 'Toro Rosso', 103.164, 0.853, 29.0], ['Räikkönen', 'Ferrari', 103.212, 0.901, 23.0], ['Vergne', 'Toro Rosso', 103.327, 1.016, 24.0], ['Bottas', 'Williams', 103.542, 1.231, 9.0], ['Massa', 'Williams', 103.741, 1.43, 22.0], ['Ricciardo', 'Red Bull', 103.821, 1.51, 25.0], ['Hülkenberg', 'Force India', 103.976, 1.665, 21.0], ['Vettel', 'Red Bull', 104.506, 2.195, 30.0], ['Sutil', 'Sauber', 104.625, 2.314, 26.0], ['Maldonado', 'Lotus', 104.876, 2.565, 26.0], ['Sirotkin', 'Sauber', 105.032, 2.721, 22.0], ['Grosjean', 'Lotus', 105.19, 2.879, 25.0], ['Merhi', 'Caterham', 106.782, 4.471, 18.0], ['Ericsson', 'Caterham', 106.922, 4.611, 18.0], ['Chilton', 'Marussia', 107.284, 4.973, 26.0]]
#
# [['Hamilton', 'Mercedes', 99.63, 0, 27.0], ['Magnussen', 'McLaren', 100.494, 0.864, 32.0], ['Alonso', 'Ferrari', 100.504, 0.874, 32.0], ['Rosberg', 'Mercedes', 100.542, 0.912, 30.0], ['Bottas', 'Williams', 100.573, 0.943, 33.0], ['Button', 'McLaren', 100.718, 1.088, 32.0], ['Massa', 'Williams', 100.731, 1.101, 30.0], ['Kvyat', 'Toro Rosso', 101.108, 1.478, 32.0], ['Vettel', 'Red Bull', 101.396, 1.766, 30.0], ['Vergne', 'Toro Rosso', 101.531, 1.901, 33.0], ['Räikkönen', 'Ferrari', 101.63, 2.0, 24.0], ['Hülkenberg', 'Force India', 101.677, 2.047, 27.0], ['Ricciardo', 'Red Bull', 102.061, 2.431, 25.0], ['Pérez', 'Force India', 102.09, 2.46, 29.0], ['Sutil', 'Sauber', 102.233, 2.603, 31.0], ['Grosjean', 'Lotus', 102.892, 3.262, 30.0], ['Maldonado', 'Lotus', 102.905, 3.275, 33.0], ['Gutiérrez', 'Sauber', 103.055, 3.425, 33.0], ['Ericsson', 'Caterham', 104.135, 4.505, 22.0], ['Chilton', 'Marussia', 104.53, 4.9, 29.0], ['Kobayashi', 'Caterham', 104.952, 5.322, 27.0]]
#
# [['Hamilton', 'Mercedes', 98.726, 0, 15.0], ['Rosberg', 'Mercedes', 99.016, 0.29, 25.0], ['Bottas', 'Williams', 99.097, 0.371, 20.0], ['Ricciardo', 'Red Bull', 99.755, 1.029, 16.0], ['Massa', 'Williams', 99.954, 1.228, 22.0], ['Kvyat', 'Toro Rosso', 100.009, 1.283, 27.0], ['Räikkönen', 'Ferrari', 100.011, 1.285, 20.0], ['Alonso', 'Ferrari', 100.151, 1.425, 15.0], ['Vergne', 'Toro Rosso', 100.205, 1.479, 26.0], ['Vettel', 'Red Bull', 100.338, 1.612, 21.0], ['Button', 'McLaren', 100.355, 1.629, 19.0], ['Hülkenberg', 'Force India', 100.669, 1.943, 23.0], ['Pérez', 'Force India', 100.699, 1.973, 26.0], ['Sutil', 'Sauber', 101.146, 2.42, 21.0], ['Gutiérrez', 'Sauber', 101.52, 2.794, 20.0], ['Grosjean', 'Lotus', 101.915, 3.189, 22.0], ['Magnussen', 'McLaren', 102.436, 3.71, 4.0], ['Ericsson', 'Caterham', 103.109, 4.383, 11.0], ['Kobayashi', 'Caterham', 103.975, 5.249, 12.0], ['Chilton', 'Marussia', 104.737, 6.011, 9.0], ['Maldonado', 'Lotus', nan, 0, 2.0]]
# working on /races/2014-united-states-grand-prix
#
# [['Hamilton', 'Mercedes', 99.941, 0, 28.0], ['Rosberg', 'Mercedes', 100.233, 0.292, 32.0], ['Button', 'McLaren', 100.319, 0.378, 27.0], ['Kvyat', 'Toro Rosso', 100.887, 0.946, 33.0], ['Magnussen', 'McLaren', 100.987, 1.046, 29.0], ['Alonso', 'Ferrari', 101.065, 1.124, 27.0], ['Vettel', 'Red Bull', 101.463, 1.522, 20.0], ['Nasr', 'Williams', 101.545, 1.604, 19.0], ['Hülkenberg', 'Force India', 101.722, 1.781, 24.0], ['Verstappen', 'Toro Rosso', 101.785, 1.844, 32.0], ['Massa', 'Williams', 101.907, 1.966, 21.0], ['Räikkönen', 'Ferrari', 101.965, 2.024, 23.0], ['Maldonado', 'Lotus', 102.329, 2.388, 28.0], ['Sutil', 'Sauber', 102.333, 2.392, 23.0], ['Pérez', 'Force India', 102.359, 2.418, 23.0], ['Gutiérrez', 'Sauber', 102.516, 2.575, 24.0], ['Ricciardo', 'Red Bull', 102.598, 2.657, 5.0], ['Grosjean', 'Lotus', 103.229, 3.288, 26.0]]
#
# [['Hamilton', 'Mercedes', 99.085, 0, 18.0], ['Rosberg', 'Mercedes', 99.088, 0.003, 34.0], ['Alonso', 'Ferrari', 100.189, 1.104, 29.0], ['Ricciardo', 'Red Bull', 100.39, 1.305, 30.0], ['Massa', 'Williams', 100.457, 1.372, 36.0], ['Räikkönen', 'Ferrari', 100.543, 1.458, 32.0], ['Kvyat', 'Toro Rosso', 100.631, 1.546, 34.0], ['Magnussen', 'McLaren', 100.641, 1.556, 38.0], ['Button', 'McLaren', 100.698, 1.613, 36.0], ['Hülkenberg', 'Force India', 100.8, 1.715, 25.0], ['Bottas', 'Williams', 100.828, 1.743, 37.0], ['Grosjean', 'Lotus', 101.054, 1.969, 31.0], ['Vergne', 'Toro Rosso', 101.11, 2.025, 36.0], ['Pérez', 'Force India', 101.123, 2.038, 35.0], ['Maldonado', 'Lotus', 101.158, 2.073, 37.0], ['Sutil', 'Sauber', 101.332, 2.247, 33.0], ['Gutiérrez', 'Sauber', 101.42, 2.335, 34.0], ['Vettel', 'Red Bull', 103.98, 4.895, 19.0]]
#
# [['Hamilton', 'Mercedes', 97.107, 0, 13.0], ['Rosberg', 'Mercedes', 97.99, 0.883, 15.0], ['Massa', 'Williams', 98.214, 1.107, 19.0], ['Bottas', 'Williams', 98.437, 1.33, 20.0], ['Alonso', 'Ferrari', 98.727, 1.62, 13.0], ['Ricciardo', 'Red Bull', 98.927, 1.82, 16.0], ['Hülkenberg', 'Force India', 98.96, 1.853, 20.0], ['Sutil', 'Sauber', 99.0, 1.893, 22.0], ['Räikkönen', 'Ferrari', 99.143, 2.036, 17.0], ['Button', 'McLaren', 99.241, 2.134, 22.0], ['Magnussen', 'McLaren', 99.335, 2.228, 19.0], ['Maldonado', 'Lotus', 99.448, 2.341, 18.0], ['Grosjean', 'Lotus', 99.561, 2.454, 21.0], ['Pérez', 'Force India', 99.582, 2.475, 21.0], ['Kvyat', 'Toro Rosso', 99.688, 2.581, 19.0], ['Gutiérrez', 'Sauber', 100.208, 3.101, 22.0], ['Vergne', 'Toro Rosso', 101.443, 4.336, 12.0], ['Vettel', 'Red Bull', 103.765, 6.658, 25.0]]
#
#
# working on /races/2014-brazilian-grand-prix
#
# [['Rosberg', 'Mercedes', 72.764, 0, 30.0], ['Hamilton', 'Mercedes', 72.985, 0.221, 32.0], ['Kvyat', 'Toro Rosso', 73.723, 0.959, 39.0], ['Alonso', 'Ferrari', 73.742, 0.978, 30.0], ['Massa', 'Williams', 73.811, 1.047, 28.0], ['Verstappen', 'Toro Rosso', 73.827, 1.063, 26.0], ['Maldonado', 'Lotus', 74.034, 1.27, 31.0], ['Räikkönen', 'Ferrari', 74.114, 1.35, 32.0], ['Magnussen', 'McLaren', 74.136, 1.372, 30.0], ['Ricciardo', 'Red Bull', 74.197, 1.433, 27.0], ['Sutil', 'Sauber', 74.434, 1.67, 31.0], ['Nasr', 'Williams', 74.522, 1.758, 22.0], ['Hülkenberg', 'Force India', 74.678, 1.914, 33.0], ['Vettel', 'Red Bull', 74.902, 2.138, 24.0], ['Grosjean', 'Lotus', 75.109, 2.345, 23.0], ['Juncadella', 'Force India', 76.03, 3.266, 17.0], ['Button', 'McLaren', nan, 0, 1.0], ['Gutiérrez', 'Sauber', nan, 0, 6.0]]
#
# [['Rosberg', 'Mercedes', 72.123, 0, 36.0], ['Hamilton', 'Mercedes', 72.336, 0.213, 36.0], ['Räikkönen', 'Ferrari', 72.696, 0.573, 32.0], ['Ricciardo', 'Red Bull', 72.956, 0.833, 24.0], ['Bottas', 'Williams', 73.035, 0.912, 31.0], ['Massa', 'Williams', 73.099, 0.976, 27.0], ['Alonso', 'Ferrari', 73.122, 0.999, 20.0], ['Kvyat', 'Toro Rosso', 73.254, 1.131, 35.0], ['Vettel', 'Red Bull', 73.333, 1.21, 28.0], ['Magnussen', 'McLaren', 73.479, 1.356, 33.0], ['Maldonado', 'Lotus', 73.497, 1.374, 33.0], ['Grosjean', 'Lotus', 73.714, 1.591, 37.0], ['Hülkenberg', 'Force India', 73.882, 1.759, 32.0], ['Gutiérrez', 'Sauber', 73.902, 1.779, 25.0], ['Sutil', 'Sauber', 74.204, 2.081, 36.0], ['Button', 'McLaren', 74.209, 2.086, 31.0], ['Vergne', 'Toro Rosso', 77.171, 5.048, 5.0]]
#
# [['Rosberg', 'Mercedes', 70.446, 0, 28.0], ['Hamilton', 'Mercedes', 70.56, 0.114, 20.0], ['Massa', 'Williams', 70.875, 0.429, 21.0], ['Bottas', 'Williams', 71.054, 0.608, 23.0], ['Ricciardo', 'Red Bull', 71.188, 0.742, 11.0], ['Button', 'McLaren', 71.21, 0.764, 19.0], ['Räikkönen', 'Ferrari', 71.316, 0.87, 15.0], ['Alonso', 'Ferrari', 71.399, 0.953, 8.0], ['Magnussen', 'McLaren', 71.499, 1.053, 19.0], ['Kvyat', 'Toro Rosso', 71.834, 1.388, 26.0], ['Vettel', 'Red Bull', 71.967, 1.521, 21.0], ['Maldonado', 'Lotus', 72.069, 1.623, 29.0], ['Sutil', 'Sauber', 72.184, 1.738, 27.0], ['Grosjean', 'Lotus', 72.235, 1.789, 30.0], ['Vergne', 'Toro Rosso', 72.235, 1.789, 29.0], ['Gutiérrez', 'Sauber', 72.286, 1.84, 24.0], ['Hülkenberg', 'Force India', 72.324, 1.878, 17.0], ['Pérez', 'Force India', 72.942, 2.496, 25.0]]
#
#
# working on /races/2014-abu-dhabi-grand-prix
#
# [['Hamilton', 'Mercedes', 103.476, 0, 32.0], ['Rosberg', 'Mercedes', 103.609, 0.133, 31.0], ['Alonso', 'Ferrari', 105.184, 1.708, 22.0], ['Vettel', 'Red Bull', 105.334, 1.858, 30.0], ['Ricciardo', 'Red Bull', 105.361, 1.885, 23.0], ['Vergne', 'Toro Rosso', 105.718, 2.242, 17.0], ['Kvyat', 'Toro Rosso', 105.835, 2.359, 32.0], ['Bottas', 'Williams', 105.913, 2.437, 8.0], ['Pérez', 'Force India', 105.983, 2.507, 23.0], ['Hülkenberg', 'Force India', 106.03, 2.554, 24.0], ['Magnussen', 'McLaren', 106.049, 2.573, 23.0], ['Räikkönen', 'Ferrari', 106.131, 2.655, 23.0], ['Massa', 'Williams', 106.549, 3.073, 7.0], ['Gutiérrez', 'Sauber', 106.556, 3.08, 28.0], ['Maldonado', 'Lotus', 106.711, 3.235, 31.0], ['Ocon', 'Lotus', 107.066, 3.59, 29.0], ['Button', 'McLaren', 107.235, 3.759, 8.0], ['Kobayashi', 'Caterham', 107.971, 4.495, 24.0], ['Fong', 'Sauber', 108.269, 4.793, 25.0], ['Stevens', 'Caterham', 110.684, 7.208, 14.0]]
#
# [['Hamilton', 'Mercedes', 102.113, 0, 35.0], ['Rosberg', 'Mercedes', 102.196, 0.083, 37.0], ['Magnussen', 'McLaren', 102.895, 0.782, 37.0], ['Vettel', 'Red Bull', 102.959, 0.846, 33.0], ['Bottas', 'Williams', 103.07, 0.957, 34.0], ['Ricciardo', 'Red Bull', 103.183, 1.07, 32.0], ['Räikkönen', 'Ferrari', 103.489, 1.376, 33.0], ['Button', 'McLaren', 103.503, 1.39, 23.0], ['Kvyat', 'Toro Rosso', 103.546, 1.433, 38.0], ['Massa', 'Williams', 103.558, 1.445, 34.0], ['Pérez', 'Force India', 103.746, 1.633, 37.0], ['Maldonado', 'Lotus', 104.005, 1.892, 38.0], ['Hülkenberg', 'Force India', 104.068, 1.955, 32.0], ['Vergne', 'Toro Rosso', 104.157, 2.044, 39.0], ['Gutiérrez', 'Sauber', 104.316, 2.203, 38.0], ['Sutil', 'Sauber', 104.763, 2.65, 37.0], ['Grosjean', 'Lotus', 104.986, 2.873, 35.0], ['Kobayashi', 'Caterham', 105.505, 3.392, 38.0], ['Stevens', 'Caterham', 107.057, 4.944, 34.0], ['Alonso', 'Ferrari', nan, 0, 2.0]]
#
# [['Rosberg', 'Mercedes', 101.424, 0, 19.0], ['Hamilton', 'Mercedes', 101.793, 0.369, 17.0], ['Massa', 'Williams', 102.429, 1.005, 18.0], ['Alonso', 'Ferrari', 102.653, 1.229, 8.0], ['Vettel', 'Red Bull', 102.679, 1.255, 19.0], ['Button', 'McLaren', 102.768, 1.344, 20.0], ['Ricciardo', 'Red Bull', 102.773, 1.349, 14.0], ['Bottas', 'Williams', 102.794, 1.37, 19.0], ['Kvyat', 'Toro Rosso', 102.809, 1.385, 20.0], ['Räikkönen', 'Ferrari', 103.038, 1.614, 14.0], ['Magnussen', 'McLaren', 103.112, 1.688, 13.0], ['Vergne', 'Toro Rosso', 103.352, 1.928, 20.0], ['Pérez', 'Force India', 103.36, 1.936, 19.0], ['Hülkenberg', 'Force India', 103.501, 2.077, 18.0], ['Gutiérrez', 'Sauber', 103.643, 2.219, 24.0], ['Maldonado', 'Lotus', 103.718, 2.294, 17.0], ['Grosjean', 'Lotus', 103.778, 2.354, 18.0], ['Sutil', 'Sauber', 104.022, 2.598, 22.0], ['Kobayashi', 'Caterham', 105.044, 3.62, 16.0], ['Stevens', 'Caterham', 105.959, 4.535, 21.0]]

# %%
F1['Qualifying Time'].fillna(value=np.nan, inplace=True)
F1 = F1.dropna()
F1['Qualifying Time'] = [convert(x) for x in F1['Qualifying Time']]

# %%
F1
# Out:
#    Season            Grand Prix      Driver   Constructor  FP1 Time  FP1 Gap  \
# 0    2023    bahrain-grand-prix       Pérez      Red Bull    92.758    0.000
# 1    2023    bahrain-grand-prix      Alonso  Aston Martin    93.196    0.438
# 2    2023    bahrain-grand-prix  Verstappen      Red Bull    93.375    0.617
# 3    2023    bahrain-grand-prix      Norris       McLaren    94.165    1.407
# 4    2023    bahrain-grand-prix     Leclerc       Ferrari    94.257    1.499
# ..    ...                   ...         ...           ...       ...      ...
# 13   2014  abu-dhabi-grand-prix   Gutiérrez        Sauber   106.556    3.080
# 14   2014  abu-dhabi-grand-prix   Maldonado         Lotus   106.711    3.235
# 16   2014  abu-dhabi-grand-prix      Button       McLaren   107.235    3.759
# 17   2014  abu-dhabi-grand-prix   Kobayashi      Caterham   107.971    4.495
# 19   2014  abu-dhabi-grand-prix     Stevens      Caterham   110.684    7.208
#
#     FP1 Laps  FP2 Time  FP2 Gap  FP2 Laps  FP3 Time FP3 Gap  FP3 Laps  \
# 0       21.0    91.078    0.171      26.0    92.446   0.106      12.0
# 1       22.0    90.907    0.000      25.0    92.340     0.0      13.0
# 2       21.0    91.076    0.169      24.0    92.345   0.005      13.0
# 3       21.0    91.570    0.663      27.0    93.202   0.862      16.0
# 4       17.0    91.367    0.460      26.0    92.624   0.284      21.0
# ..       ...       ...      ...       ...       ...     ...       ...
# 13      28.0   104.316    2.203      38.0   103.643   2.219      24.0
# 14      31.0   104.005    1.892      38.0   103.718   2.294      17.0
# 16       8.0   103.503    1.390      23.0   102.768   1.344      20.0
# 17      24.0   105.505    3.392      38.0   105.044    3.62      16.0
# 19      14.0   107.057    4.944      34.0   105.959   4.535      21.0
#
#    Grid Position  Qualifying Time
# 0              2           91.479
# 1              5           91.158
# 2              1           91.295
# 3             11           91.652
# 4              3           91.094
# ..           ...              ...
# 13          15.0          102.819
# 14          16.0          102.860
# 16           6.0          102.137
# 17          17.0          104.540
# 19          18.0          105.095
#
# [3248 rows x 15 columns]

# %%
filename = 'WORKINGF1Data.csv'

# %%
F1.to_csv(filename, sep=',', index=False, encoding='utf-8')
